# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import os
from selenium.webdriver.support.ui import Select
import time
import csv
from csv import DictWriter
from collections import OrderedDict
import xlsxwriter
import dask.dataframe as dd
import numpy as np

column_name = ["SEMIS ID", "SEMIS ID (DC)", "SEMIS ID (M&E)", "Status"]

dict = {}

#data_f = pd.read_csv(r'E:/DGME/allteachers.csv', usecols = columns, low_memory=False)

# %%
col_mm = ["School_SEMIS_Code", "School_Name", "Active_Ind"]
data_mm = pd.read_excel(r'E:/DGME/work/MNE_Schools.xlsx', usecols = col_mm , sheet_name="sheet")

data_mm = pd.DataFrame(data_mm)
data_mm = data_mm.loc[data_mm['Active_Ind']==1]
#data_mm = data_mm[0:100]

data_mm['School_SEMIS_Code'] = data_mm['School_SEMIS_Code'].astype(np.int64)
data_mm['Active_Ind'] = data_mm['Active_Ind'].astype(np.int64())
print(data_mm['School_SEMIS_Code'].dtype, data_mm['Active_Ind'].dtype)

data_mm.head()
# Out:
# int64 int64
#             School_Name  School_SEMIS_Code  Active_Ind
# 0   GGPS:ALI NAWAZ MARI          111669829           1
# 1  MUHAMMADI ILYAS GOTH          100000001           1
# 2              K.T.S 24          100000002           1
# 3          IBRAHIN GOTH          100000003           1
# 4            KEAMARI 02          100000004           1

# %%
df_mm = data_mm[10000 :20000]
df_mm
# Out:
#                        School_Name  School_SEMIS_Code  Active_Ind
# 10000         GIAND KHASKHALI (BR)          404080412           1
# 10001                 DANYAL MASIH          404080413           1
# 10002             NABI BUX HATHYAR          404080414           1
# 10003  MUHAMMMAD ACHAR LOTHEIO(BR)          404080415           1
# 10004          KAHERI MUHLLLA (BR)          404080416           1
# ...                            ...                ...         ...
# 19995                   T.M COLONY          407060316           1
# 19996                  MITHO KHOSO          407060317           1
# 19997                 MULLA MAKHAN          407060318           1
# 19998                 KUMB DARHOON          407060319           1
# 19999             HAJI SANJAR KHAN          407060320           1
#
# [10000 rows x 3 columns]

# %%
url = "http://checker.sindheducation.gov.pk/CheckBiometrics.aspx"

# create a new Chrome session
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(5)


# Search DDL
search_ddl = driver.find_element_by_id("ContentPlaceHolder1_ddlSearchBy")
select = Select(search_ddl)
select.select_by_index(2)
time.sleep(4)
data = True
i = 1
for index, row in df_mm.iterrows():
    for j in range(3):        
        search_text = driver.find_element_by_id("ContentPlaceHolder1_txtSearch")
        search_text.click()
        search_text.clear()
        search_text.send_keys(row['School_SEMIS_Code'])
        search_text.send_keys(Keys.ENTER)
        time.sleep(1)
        search_button = driver.find_element_by_id("ContentPlaceHolder1_btn_search")
        search_button.click()
        time.sleep(6)
        break 

    try:
        data_set = driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[15]')
        semid_dc =  driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[9]')
        semid_me =  driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[12]')
        semid_sg = semid_dc.get_attribute('innerText')
        semid_mm = semid_me.get_attribute('innerText')
        
        #if (semid_dc == semid_me ):
            
        dict[column_name[0]] = row['School_SEMIS_Code']
        dict[column_name[1]] = semid_sg
        dict[column_name[2]] = semid_mm
        dict[column_name[3]] = data_set.get_attribute('innerText')
        print("Record " + str(i) + ": Record Found")
        # data = True
    except:
        dict[column_name[0]] = row['School_SEMIS_Code']
        dict[column_name[3]] = 'Not Found'
        print("Record " + str(i) + ": Not Found")
        # data = False
        # break
    driver.implicitly_wait(3)
    with open(r'D:\SchoolsRecordSet_Status\Status_ActiveSchool_Recordset.csv', 'a', newline='') as f_object:
        dictwriter_object = csv.DictWriter(f_object, fieldnames=column_name)
        if index == 0:
            dictwriter_object.writeheader()
        dictwriter_object.writerow(dict)
        dict.clear()
    i = i + 1;
    
driver.quit();
print("Completed")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [C:\Users\Dell\.wdm\drivers\chromedriver\win32\89.0.4389.23\chromedriver.exe] found in c
# Record 697: Not Found
# Record 698: Not Found
# Record 699: Not Found
# Record 700: Not Found
# Record 701: Not Found
# Record 702: Not Found
# Record 703: Not Found
# Record 704: Not Found
# Record 705: Not Found
# Record 706: Not Found
# Record 707: Not Found
# Record 708: Not Found
# Record 709: Not Found
# Record 710: Not Found
# Record 711: Not Found
# Record 712: Not Found
# Record 713: Not Found
# Record 714: Not Found
# Record 715: Not Found
# Record 716: Not Found
# Record 717: Not Found
# Record 718: Not Found
# Record 719: Not Found
# Record 720: Not Found
# Record 721: Not Found
# Record 722: Not Found
# Record 723: Not Found
# Record 724: Not Found
# Record 725: Not Found
# Record 726: Not Found
# Record 727: Not Found
# Record 728: Not Found
# Record 729: Not Found
# Record 730: Not Found
# Record 731: Not Found
# Record 732: Not Found
# Record 733: Not Found
# Record 734: Not Found
# Record 735: Not Found
# Record 736: Not Found
# Record 737: Not Found
# Record 738: Not Found
# Record 739: Not Found
# Record 740: Not Found
# Record 741: Not Found
# Record 742: Not Found
# Record 743: Not Found
# Record 744: Not Found
# Record 745: Not Found
# Record 746: Not Found
# Record 747: Not Found
# Record 748: Not Found
# Record 749: Not Found
# Record 750: Not Found
# Record 751: Not Found
# Record 752: Not Found
# Record 753: Not Found
# Record 754: Not Found
# Record 755: Not Found
# Record 756: Not Found
# Record 757: Not Found
# Record 758: Not Found
# Record 759: Not Found
# Record 760: Not Found
# Record 761: Not Found
# Record 762: Not Found
# Record 763: Not Found
# Record 764: Record Found
# Record 765: Record Found
# Record 766: Record Found
# Record 767: Record Found
# Record 768: Record Found
# Record 769: Record Found
# Record 770: Record Found
# Record 771: Record Found
# Record 772: Record Found
# Record 773: Record Found
# Record 774: Record Found
# Record 775: Record Found
# Record 776: Record Found
# Record 777: Record Found
# Record 778: Record Found
# Record 779: Record Found
# Record 780: Record Found
# Record 781: Record Found
# Record 782: Record Found
# Record 783: Record Found
# Record 784: Record Found
# Record 785: Record Found
# Record 786: Record Found
# Record 787: Record Found
# Record 788: Record Found
# Record 789: Record Found
# Record 790: Record Found
# Record 791: Record Found
# Record 792: Record Found
# Record 793: Record Found
# Record 794: Record Found
# Record 795: Record Found
# Record 796: Record Found
# Record 797: Record Found
# Record 798: Record Found
# Record 799: Record Found
# Record 800: Record Found
# Record 801: Record Found
# Record 802: Record Found
# Record 803: Record Found
# Record 804: Record Found
# Record 805: Record Found
# Record 806: Record Found
# Record 807: Record Found
# Record 808: Record Found
# Record 809: Record Found
# Record 810: Record Found
# Record 811: Record Found
# Record 812: Record Found
# Record 813: Record Found
# Record 814: Record Found
# Record 815: Record Found
# Record 816: Record Found
# Record 817: Record Found
# Record 818: Record Found
# Record 819: Record Found
# Record 820: Record Found
# Record 821: Record Found
# Record 822: Record Found
# Record 823: Record Found
# Record 824: Record Found
# Record 825: Record Found
# Record 826: Record Found
# Record 827: Record Found
# Record 828: Record Found
# Record 829: Record Found
# Record 830: Record Found
# Record 831: Record Found
# Record 832: Record Found
# Record 833: Record Found
# Record 834: Record Found
# Record 835: Record Found
# Record 836: Record Found
# Record 837: Record Found
# Record 838: Record Found
# Record 839: Record Found
# Record 840: Record Found
# Record 841: Record Found
# Record 842: Record Found
# Record 843: Record Found
# Record 844: Record Found
# Record 845: Record Found
# Record 846: Record Found
# Record 847: Record Found
# Record 848: Record Found
# Record 849: Record Found
# Record 850: Record Found
# Record 851: Record Found
# Record 852: Record Found
# Record 853: Record Found
# Record 854: Record Found
# Record 855: Record Found
# Record 856: Record Found
# Record 857: Record Found
# Record 858: Record Found
# Record 859: Record Found
# Record 860: Record Found
# Record 861: Record Found
# Record 862: Record Found
# Record 863: Record Found
# Record 864: Record Found
# Record 865: Record Found
# Record 866: Record Found
# Record 867: Record Found
# Record 868: Record Found
# Record 869: Record Found
# Record 870: Record Found
# Record 871: Record Found
# Record 872: Record Found
# Record 873: Record Found
# Record 874: Record Found
# Record 875: Record Found
# Record 876: Record Found
# Record 877: Record Found
# Record 878: Record Found
# Record 879: Record Found
# Record 880: Record Found
# Record 881: Record Found
# Record 882: Record Found
# Record 883: Record Found
# Record 884: Record Found
# Record 885: Record Found
# Record 886: Record Found
# Record 887: Record Found
# Record 888: Record Found
# Record 889: Record Found
# Record 890: Record Found
# Record 891: Record Found
# Record 892: Record Found
# Record 893: Record Found
# Record 894: Record Found
# Record 895: Record Found
# Record 896: Record Found
# Record 897: Record Found
# Record 898: Record Found
# Record 899: Record Found
# Record 900: Record Found
# Record 901: Record Found
# Record 902: Record Found
# Record 903: Record Found
# Record 904: Record Found
# Record 905: Record Found
# Record 906: Record Found
# Record 907: Record Found
# Record 908: Record Found
# Record 909: Record Found
# Record 910: Record Found
# Record 911: Record Found
# Record 912: Record Found
# Record 913: Record Found
# Record 914: Record Found
# Record 915: Record Found
# Record 916: Record Found
# Record 917: Record Found
# Record 918: Record Found
# Record 919: Record Found
# Record 920: Record Found
# Record 921: Record Found
# Record 922: Record Found
# Record 923: Record Found
# Record 924: Record Found
# Record 925: Record Found
# Record 926: Record Found
# Record 927: Record Found
# Record 928: Record Found
# Record 929: Record Found
# Record 930: Record Found
# Record 931: Record Found
# Record 932: Record Found
# Record 933: Record Found
# Record 934: Record Found
# Record 935: Record Found
# Record 936: Record Found
# Record 937: Record Found
# Record 938: Record Found
# Record 939: Record Found
# Record 940: Record Found
# Record 941: Record Found
# Record 942: Record Found
# Record 943: Record Found
# Record 944: Record Found
# Record 945: Record Found
# Record 946: Record Found
# Record 947: Record Found
# Record 948: Record Found
# Record 949: Record Found
# Record 950: Record Found
# Record 951: Record Found
# Record 952: Record Found
# Record 953: Record Found
# Record 954: Record Found
# Record 955: Record Found
# Record 956: Record Found
# Record 957: Record Found
# Record 958: Record Found
# Record 959: Record Found
# Record 960: Record Found
# Record 961: Record Found
# Record 962: Record Found
# Record 963: Record Found
# Record 964: Record Found
# Record 965: Record Found
# Record 966: Record Found
# Record 967: Record Found
# Record 968: Record Found
# Record 969: Record Found
# Record 970: Record Found
# Record 971: Record Found
# Record 972: Record Found
# Record 973: Record Found
# Record 974: Record Found
# Record 975: Record Found
# Record 976: Record Found
# Record 977: Record Found
# Record 978: Record Found
# Record 979: Record Found
# Record 980: Record Found
# Record 981: Record Found
# Record 982: Record Found
# Record 983: Record Found
# Record 984: Record Found
# Record 985: Record Found
# Record 986: Record Found
# Record 987: Record Found
# Record 988: Record Found
# Record 989: Record Found
# Record 990: Record Found
# Record 991: Record Found
# Record 992: Record Found
# Record 993: Record Found
# Record 994: Record Found
# Record 995: Record Found
# Record 996: Record Found
# Record 997: Record Found
# Record 998: Record Found
# Record 999: Record Found
# Record 1000: Record Found
# Record 1001: Record Found
# Record 1002: Record Found
# Record 1003: Record Found
# Record 1004: Record Found
# Record 1005: Record Found
# Record 1006: Record Found
# Record 1007: Record Found
# Record 1008: Record Found
# Record 1009: Record Found
# Record 1010: Record Found
# Record 1011: Record Found
# Record 1012: Record Found
# Record 1013: Record Found
# Record 1014: Record Found
# Record 1015: Record Found
# Record 1016: Record Found
# Record 1017: Record Found
# Record 1018: Record Found
# Record 1019: Record Found
# Record 1020: Record Found
# Record 1021: Record Found
# Record 1022: Record Found
# Record 1023: Record Found
# Record 1024: Record Found
# Record 1025: Record Found
# Record 1026: Record Found
# Record 1027: Record Found
# Record 1028: Record Found
# Record 1029: Record Found
# Record 1030: Record Found
# Record 1031: Record Found
# Record 1032: Record Found
# Record 1033: Record Found
# Record 1034: Record Found
# Record 1035: Record Found
# Record 1036: Record Found
# Record 1037: Record Found
# Record 1038: Record Found
# Record 1039: Record Found
# Record 1040: Record Found
# Record 1041: Record Found
# Record 1042: Record Found
# Record 1043: Record Found
# Record 1044: Record Found
# Record 1045: Record Found
# Record 1046: Record Found
# Record 1047: Record Found
# Record 1048: Record Found
# Record 1049: Record Found
# Record 1050: Record Found
# Record 1051: Record Found
# Record 1052: Record Found
# Record 1053: Record Found
# Record 1054: Record Found
# Record 1055: Record Found
# Record 1056: Record Found
# Record 1057: Record Found
# Record 1058: Record Found
# Record 1059: Record Found
# Record 1060: Record Found
# Record 1061: Record Found
# Record 1062: Record Found
# Record 1063: Record Found
# Record 1064: Record Found
# Record 1065: Record Found
# Record 1066: Record Found
# Record 1067: Record Found
# Record 1068: Record Found
# Record 1069: Record Found
# Record 1070: Record Found
# Record 1071: Record Found
# Record 1072: Record Found
# Record 1073: Record Found
# Record 1074: Record Found
# Record 1075: Record Found
# Record 1076: Record Found
# Record 1077: Record Found
# Record 1078: Record Found
# Record 1079: Record Found
# Record 1080: Record Found
# Record 1081: Record Found
# Record 1082: Record Found
# Record 1083: Record Found
# Record 1084: Record Found
# Record 1085: Record Found
# Record 1086: Record Found
# Record 1087: Record Found
# Record 1088: Record Found
# Record 1089: Record Found
# Record 1090: Record Found
# Record 1091: Record Found
# Record 1092: Record Found
# Record 1093: Record Found
# Record 1094: Record Found
# Record 1095: Record Found
# Record 1096: Record Found
# Record 1097: Record Found
# Record 1098: Record Found
# Record 1099: Record Found
# Record 1100: Record Found
# Record 1101: Record Found
# Record 1102: Record Found
# Record 1103: Record Found
# Record 1104: Record Found
# Record 1105: Record Found
# Record 1106: Record Found
# Record 1107: Record Found
# Record 1108: Record Found
# Record 1109: Record Found
# Record 1110: Record Found
# Record 1111: Record Found
# Record 1112: Record Found
# Record 1113: Record Found
# Record 1114: Record Found
# Record 1115: Record Found
# Record 1116: Record Found
# Record 1117: Record Found
# Record 1118: Record Found
# Record 1119: Record Found
# Record 1120: Record Found
# Record 1121: Record Found
# Record 1122: Record Found
# Record 1123: Record Found
# Record 1124: Record Found
# Record 1125: Record Found
# Record 1126: Record Found
# Record 1127: Record Found
# Record 1128: Record Found
# Record 1129: Record Found
# Record 1130: Record Found
# Record 1131: Record Found
# Record 1132: Record Found
# Record 1133: Record Found
# Record 1134: Record Found
# Record 1135: Record Found
# Record 1136: Record Found
# Record 1137: Record Found
# Record 1138: Record Found
# Record 1139: Record Found
# Record 1140: Record Found
# Record 1141: Record Found
# Record 1142: Record Found
# Record 1143: Record Found
# Record 1144: Record Found
# Record 1145: Record Found
# Record 1146: Record Found
# Record 1147: Record Found
# Record 1148: Record Found
# Record 1149: Record Found
# Record 1150: Record Found
# Record 1151: Record Found
# Record 1152: Record Found
# Record 1153: Record Found
# Record 1154: Record Found
# Record 1155: Record Found
# Record 1156: Record Found
# Record 1157: Record Found
# Record 1158: Record Found
# Record 1159: Record Found
# Record 1160: Record Found
# Record 1161: Record Found
# Record 1162: Record Found
# Record 1163: Record Found
# Record 1164: Record Found
# Record 1165: Record Found
# Record 1166: Record Found
# Record 1167: Record Found
# Record 1168: Record Found
# Record 1169: Record Found
# Record 1170: Record Found
# Record 1171: Record Found
# Record 1172: Record Found
# Record 1173: Record Found
# Record 1174: Record Found
# Record 1175: Record Found
# Record 1176: Record Found
# Record 1177: Record Found
# Record 1178: Record Found
# Record 1179: Record Found
# Record 1180: Record Found
# Record 1181: Record Found
# Record 1182: Record Found
# Record 1183: Record Found
# Record 1184: Record Found
# Record 1185: Record Found
# Record 1186: Record Found
# Record 1187: Record Found
# Record 1188: Record Found
# Record 1189: Record Found
# Record 1190: Record Found
# Record 1191: Record Found
# Record 1192: Record Found
# Record 1193: Record Found
# Record 1194: Record Found
# Record 1195: Record Found
# Record 1196: Record Found
# Record 1197: Record Found
# Record 1198: Record Found
# Record 1199: Record Found
# Record 1200: Record Found
# Record 1201: Record Found
# Record 1202: Record Found
# Record 1203: Record Found
# Record 1204: Record Found
# Record 1205: Record Found
# Record 1206: Record Found
# Record 1207: Record Found
# Record 1208: Record Found
# Record 1209: Record Found
# Record 1210: Record Found
# Record 1211: Record Found
# Record 1212: Record Found
# Record 1213: Record Found
# Record 1214: Record Found
# Record 1215: Record Found
# Record 1216: Record Found
# Record 1217: Record Found
# Record 1218: Record Found
# Record 1219: Record Found
# Record 1220: Record Found
# Record 1221: Record Found
# Record 1222: Record Found
# Record 1223: Record Found
# Record 1224: Record Found
# Record 1225: Record Found
# Record 1226: Record Found
# Record 1227: Record Found
# Record 1228: Record Found
# Record 1229: Record Found
# Record 1230: Record Found
# Record 1231: Record Found
# Record 1232: Record Found
# Record 1233: Record Found
# Record 1234: Record Found
# Record 1235: Record Found
# Record 1236: Record Found
# Record 1237: Record Found
# Record 1238: Record Found
# Record 1239: Record Found
# Record 1240: Record Found
# Record 1241: Record Found
# Record 1242: Record Found
# Record 1243: Record Found
# Record 1244: Record Found
# Record 1245: Record Found
# Record 1246: Record Found
# Record 1247: Record Found
# Record 1248: Record Found
# Record 1249: Record Found
# Record 1250: Record Found
# Record 1251: Record Found
# Record 1252: Record Found
# Record 1253: Record Found
# Record 1254: Record Found
# Record 1255: Record Found
# Record 1256: Record Found
# Record 1257: Record Found
# Record 1258: Record Found
# Record 1259: Record Found
# Record 1260: Record Found
# Record 1261: Record Found
# Record 1262: Record Found
# Record 1263: Record Found
# Record 1264: Record Found
# Record 1265: Record Found
# Record 1266: Record Found
# Record 1267: Record Found
# Record 1268: Record Found
# Record 1269: Record Found
# Record 1270: Record Found
# Record 1271: Record Found
# Record 1272: Record Found
# Record 1273: Record Found
# Record 1274: Record Found
# Record 1275: Record Found
# Record 1276: Record Found
# Record 1277: Record Found
# Record 1278: Record Found
# Record 1279: Record Found
# Record 1280: Record Found
# Record 1281: Record Found
# Record 1282: Record Found
# Record 1283: Record Found
# Record 1284: Record Found
# Record 1285: Record Found
# Record 1286: Record Found
# Record 1287: Record Found
# Record 1288: Record Found
# Record 1289: Record Found
# Record 1290: Record Found
# Record 1291: Record Found
# Record 1292: Record Found
# Record 1293: Record Found
# Record 1294: Record Found
# Record 1295: Record Found
# Record 1296: Record Found
# Record 1297: Record Found
# Record 1298: Record Found
# Record 1299: Record Found
# Record 1300: Record Found
# Record 1301: Record Found
# Record 1302: Record Found
# Record 1303: Record Found
# Record 1304: Record Found
# Record 1305: Record Found
# Record 1306: Record Found
# Record 1307: Record Found
# Record 1308: Record Found
# Record 1309: Record Found
# Record 1310: Record Found
# Record 1311: Record Found
# Record 1312: Record Found
# Record 1313: Record Found
# Record 1314: Record Found
# Record 1315: Record Found
# Record 1316: Record Found
# Record 1317: Record Found
# Record 1318: Record Found
# Record 1319: Record Found
# Record 1320: Record Found
# Record 1321: Record Found
# Record 1322: Record Found
# Record 1323: Record Found
# Record 1324: Record Found
# Record 1325: Record Found
# Record 1326: Record Found
# Record 1327: Record Found
# Record 1328: Record Found
# Record 1329: Record Found
# Record 1330: Record Found
# Record 1331: Record Found
# Record 1332: Record Found
# Record 1333: Record Found
# Record 1334: Record Found
# Record 1335: Record Found
# Record 1336: Record Found
# Record 1337: Record Found
# Record 1338: Record Found
# Record 1339: Record Found
# Record 1340: Record Found
# Record 1341: Record Found
# Record 1342: Record Found
# Record 1343: Record Found
# Record 1344: Record Found
# Record 1345: Record Found
# Record 1346: Record Found
# Record 1347: Record Found
# Record 1348: Record Found
# Record 1349: Record Found
# Record 1350: Record Found
# Record 1351: Record Found
# Record 1352: Record Found
# Record 1353: Record Found
# Record 1354: Record Found
# Record 1355: Record Found
# Record 1356: Record Found
# Record 1357: Record Found
# Record 1358: Record Found
# Record 1359: Record Found
# Record 1360: Record Found
# Record 1361: Record Found
# Record 1362: Record Found
# Record 1363: Record Found
# Record 1364: Record Found
# Record 1365: Record Found
# Record 1366: Record Found
# Record 1367: Record Found
# Record 1368: Record Found
# Record 1369: Record Found
# Record 1370: Record Found
# Record 1371: Record Found
# Record 1372: Record Found
# Record 1373: Record Found
# Record 1374: Record Found
# Record 1375: Record Found
# Record 1376: Record Found
# Record 1377: Record Found
# Record 1378: Record Found
# Record 1379: Record Found
# Record 1380: Record Found
# Record 1381: Record Found
# Record 1382: Record Found
# Record 1383: Record Found
# Record 1384: Record Found
# Record 1385: Record Found
# Record 1386: Record Found
# Record 1387: Record Found
# Record 1388: Record Found
# Record 1389: Record Found
# Record 1390: Record Found
# Record 1391: Record Found
# Record 1392: Record Found
# Record 1393: Record Found
# Record 1394: Record Found
# Record 1395: Record Found
# Record 1396: Record Found
# Record 1397: Record Found
# Record 1398: Record Found
# Record 1399: Record Found
# Record 1400: Record Found
# Record 1401: Record Found
# Record 1402: Record Found
# Record 1403: Record Found
# Record 1404: Record Found
# Record 1405: Record Found
# Record 1406: Record Found
# Record 1407: Record Found
# Record 1408: Record Found
# Record 1409: Record Found
# Record 1410: Record Found
# Record 1411: Record Found
# Record 1412: Record Found
# Record 1413: Record Found
# Record 1414: Record Found
# Record 1415: Record Found
# Record 1416: Record Found
# Record 1417: Record Found
# Record 1418: Record Found
# Record 1419: Record Found
# Record 1420: Record Found
# Record 1421: Record Found
# Record 1422: Record Found
# Record 1423: Record Found
# Record 1424: Record Found
# Record 1425: Record Found
# Record 1426: Record Found
# Record 1427: Record Found
# Record 1428: Record Found
# Record 1429: Record Found
# Record 1430: Record Found
# Record 1431: Record Found
# Record 1432: Record Found
# Record 1433: Record Found
# Record 1434: Record Found
# Record 1435: Record Found
# Record 1436: Record Found
# Record 1437: Record Found
# Record 1438: Record Found
# Record 1439: Record Found
# Record 1440: Record Found
# Record 1441: Record Found
# Record 1442: Record Found
# Record 1443: Record Found
# Record 1444: Record Found
# Record 1445: Record Found
# Record 1446: Record Found
# Record 1447: Record Found
# Record 1448: Record Found
# Record 1449: Record Found
# Record 1450: Record Found
# Record 1451: Record Found
# Record 1452: Record Found
# Record 1453: Record Found
# Record 1454: Record Found
# Record 1455: Record Found
# Record 1456: Record Found
# Record 1457: Record Found
# Record 1458: Record Found
# Record 1459: Record Found
# Record 1460: Record Found
# Record 1461: Record Found
# Record 1462: Record Found
# Record 1463: Record Found
# Record 1464: Record Found
# Record 1465: Record Found
# Record 1466: Record Found
# Record 1467: Record Found
# Record 1468: Record Found
# Record 1469: Record Found
# Record 1470: Record Found
# Record 1471: Record Found
# Record 1472: Record Found
# Record 1473: Record Found
# Record 1474: Record Found
# Record 1475: Record Found
# Record 1476: Record Found
# Record 1477: Record Found
# Record 1478: Record Found
# Record 1479: Record Found
# Record 1480: Record Found
# Record 1481: Record Found
# Record 1482: Record Found
# Record 1483: Record Found
# Record 1484: Record Found
# Record 1485: Record Found
# Record 1486: Record Found
# Record 1487: Record Found
# Record 1488: Record Found
# Record 1489: Record Found
# Record 1490: Record Found
# Record 1491: Record Found
# Record 1492: Record Found
# Record 1493: Record Found
# Record 1494: Record Found
# Record 1495: Record Found
# Record 1496: Record Found
# Record 1497: Record Found
# Record 1498: Record Found
# Record 1499: Record Found
# Record 1500: Record Found
# Record 1501: Record Found
# Record 1502: Record Found
# Record 1503: Record Found
# Record 1504: Record Found
# Record 1505: Record Found
# Record 1506: Record Found
# Record 1507: Record Found
# Record 1508: Record Found
# Record 1509: Record Found
# Record 1510: Record Found
# Record 1511: Record Found
# Record 1512: Record Found
# Record 1513: Record Found
# Record 1514: Record Found
# Record 1515: Record Found
# Record 1516: Record Found
# Record 1517: Record Found
# Record 1518: Record Found
# Record 1519: Record Found
# Record 1520: Record Found
# Record 1521: Record Found
# Record 1522: Record Found
# Record 1523: Record Found
# Record 1524: Record Found
# Record 1525: Record Found
# Record 1526: Record Found
# Record 1527: Record Found
# Record 1528: Record Found
# Record 1529: Record Found
# Record 1530: Record Found
# Record 1531: Record Found
# Record 1532: Record Found
# Record 1533: Record Found
# Record 1534: Record Found
# Record 1535: Record Found
# Record 1536: Record Found
# Record 1537: Record Found
# Record 1538: Record Found
# Record 1539: Record Found
# Record 1540: Record Found
# Record 1541: Record Found
# Record 1542: Record Found
# Record 1543: Record Found
# Record 1544: Record Found
# Record 1545: Record Found
# Record 1546: Record Found
# Record 1547: Record Found
# Record 1548: Record Found
# Record 1549: Record Found
# Record 1550: Record Found
# Record 1551: Record Found
# Record 1552: Record Found
# Record 1553: Record Found
# Record 1554: Record Found
# Record 1555: Record Found
# Record 1556: Record Found
# Record 1557: Record Found
# Record 1558: Record Found
# Record 1559: Record Found
# Record 1560: Record Found
# Record 1561: Record Found
# Record 1562: Record Found
# Record 1563: Record Found
# Record 1564: Record Found
# Record 1565: Record Found
# Record 1566: Record Found
# Record 1567: Record Found
# Record 1568: Record Found
# Record 1569: Record Found
# Record 1570: Record Found
# Record 1571: Record Found
# Record 1572: Record Found
# Record 1573: Record Found
# Record 1574: Record Found
# Record 1575: Record Found
# Record 1576: Record Found
# Record 1577: Record Found
# Record 1578: Record Found
# Record 1579: Record Found
# Record 1580: Record Found
# Record 1581: Record Found
# Record 1582: Record Found
# Record 1583: Record Found
# Record 1584: Record Found
# Record 1585: Record Found
# Record 1586: Record Found
# Record 1587: Record Found
# Record 1588: Record Found
# Record 1589: Record Found
# Record 1590: Record Found
# Record 1591: Record Found
# Record 1592: Record Found
# Record 1593: Record Found
# Record 1594: Record Found
# Record 1595: Record Found
# Record 1596: Record Found
# Record 1597: Record Found
# Record 1598: Record Found
# Record 1599: Record Found
# Record 1600: Record Found
# Record 1601: Record Found
# Record 1602: Record Found
# Record 1603: Record Found
# Record 1604: Record Found
# Record 1605: Record Found
# Record 1606: Record Found
# Record 1607: Record Found
# Record 1608: Record Found
# Record 1609: Record Found
# Record 1610: Record Found
# Record 1611: Record Found
# Record 1612: Record Found
# Record 1613: Record Found
# Record 1614: Record Found
# Record 1615: Record Found
# Record 1616: Record Found
# Record 1617: Record Found
# Record 1618: Record Found
# Record 1619: Record Found
# Record 1620: Record Found
# Record 1621: Record Found
# Record 1622: Record Found
# Record 1623: Record Found
# Record 1624: Record Found
# Record 1625: Record Found
# Record 1626: Record Found
# Record 1627: Record Found
# Record 1628: Record Found
# Record 1629: Record Found
# Record 1630: Record Found
# Record 1631: Record Found
# Record 1632: Record Found
# Record 1633: Record Found
# Record 1634: Record Found
# Record 1635: Record Found
# Record 1636: Record Found
# Record 1637: Record Found
# Record 1638: Record Found
# Record 1639: Record Found
# Record 1640: Record Found
# Record 1641: Record Found
# Record 1642: Record Found
# Record 1643: Record Found
# Record 1644: Record Found
# Record 1645: Record Found
# Record 1646: Record Found
# Record 1647: Record Found
# Record 1648: Record Found
# Record 1649: Record Found
# Record 1650: Record Found
# Record 1651: Record Found
# Record 1652: Record Found
# Record 1653: Record Found
# Record 1654: Record Found
# Record 1655: Record Found
# Record 1656: Record Found
# Record 1657: Record Found
# Record 1658: Record Found
# Record 1659: Record Found
# Record 1660: Record Found
# Record 1661: Record Found
# Record 1662: Record Found
# Record 1663: Record Found
# Record 1664: Record Found
# Record 1665: Record Found
# Record 1666: Record Found
# Record 1667: Record Found
# Record 1668: Record Found
# Record 1669: Record Found
# Record 1670: Record Found
# Record 1671: Record Found
# Record 1672: Record Found
# Record 1673: Record Found
# Record 1674: Record Found
# Record 1675: Record Found
# Record 1676: Record Found
# Record 1677: Record Found
# Record 1678: Record Found
# Record 1679: Record Found
# Record 1680: Record Found
# Record 1681: Record Found
# Record 1682: Record Found
# Record 1683: Record Found
# Record 1684: Record Found
# Record 1685: Record Found
# Record 1686: Record Found
# Record 1687: Record Found
# Record 1688: Record Found
# Record 1689: Record Found
# Record 1690: Record Found
# Record 1691: Record Found
# Record 1692: Record Found
# Record 1693: Record Found
# Record 1694: Record Found
# Record 1695: Record Found
# Record 1696: Record Found
# Record 1697: Record Found
# Record 1698: Record Found
# Record 1699: Record Found
# Record 1700: Record Found
# Record 1701: Record Found
# Record 1702: Record Found
# Record 1703: Record Found
# Record 1704: Record Found
# Record 1705: Record Found
# Record 1706: Record Found
# Record 1707: Record Found
# Record 1708: Record Found
# Record 1709: Record Found
# Record 1710: Record Found
# Record 1711: Record Found
# Record 1712: Record Found
# Record 1713: Record Found
# Record 1714: Record Found
# Record 1715: Record Found
# Record 1716: Record Found
# Record 1717: Record Found
# Record 1718: Record Found
# Record 1719: Record Found
# Record 1720: Record Found
# Record 1721: Record Found
# Record 1722: Record Found
# Record 1723: Record Found
# Record 1724: Record Found
# Record 1725: Record Found
# Record 1726: Record Found
# Record 1727: Record Found
# Record 1728: Record Found
# Record 1729: Record Found
# Record 1730: Record Found
# Record 1731: Record Found
# Record 1732: Record Found
# Record 1733: Record Found
# Record 1734: Record Found
# Record 1735: Record Found
# Record 1736: Record Found
# Record 1737: Record Found
# Record 1738: Record Found
# Record 1739: Record Found
# Record 1740: Record Found
# Record 1741: Record Found
# Record 1742: Record Found
# Record 1743: Record Found
# Record 1744: Record Found
# Record 1745: Record Found
# Record 1746: Record Found
# Record 1747: Record Found
# Record 1748: Record Found
# Record 1749: Record Found
# Record 1750: Record Found
# Record 1751: Record Found
# Record 1752: Record Found
# Record 1753: Record Found
# Record 1754: Record Found
# Record 1755: Record Found
# Record 1756: Record Found
# Record 1757: Record Found
# Record 1758: Record Found
# Record 1759: Record Found
# Record 1760: Record Found
# Record 1761: Record Found
# Record 1762: Record Found
# Record 1763: Record Found
# Record 1764: Record Found
# Record 1765: Record Found
# Record 1766: Record Found
# Record 1767: Record Found
# Record 1768: Record Found
# Record 1769: Record Found
# Record 1770: Record Found
# Record 1771: Record Found
# Record 1772: Record Found
# Record 1773: Record Found
# Record 1774: Record Found
# Record 1775: Record Found
# Record 1776: Record Found
# Record 1777: Record Found
# Record 1778: Record Found
# Record 1779: Record Found
# Record 1780: Record Found
# Record 1781: Record Found
# Record 1782: Record Found
# Record 1783: Record Found
# Record 1784: Record Found
# Record 1785: Record Found
# Record 1786: Record Found
# Record 1787: Record Found
# Record 1788: Record Found
# Record 1789: Record Found
# Record 1790: Record Found
# Record 1791: Record Found
# Record 1792: Record Found
# Record 1793: Record Found
# Record 1794: Record Found
# Record 1795: Record Found
# Record 1796: Record Found
# Record 1797: Record Found
# Record 1798: Record Found
# Record 1799: Record Found
# Record 1800: Record Found
# Record 1801: Record Found
# Record 1802: Record Found
# Record 1803: Record Found
# Record 1804: Record Found
# Record 1805: Record Found
# Record 1806: Record Found
# Record 1807: Record Found
# Record 1808: Record Found
# Record 1809: Record Found
# Record 1810: Record Found
# Record 1811: Record Found
# Record 1812: Record Found
# Record 1813: Record Found
# Record 1814: Record Found
# Record 1815: Record Found
# Record 1816: Record Found
# Record 1817: Record Found
# Record 1818: Record Found
# Record 1819: Record Found
# Record 1820: Record Found
# Record 1821: Record Found
# Record 1822: Record Found
# Record 1823: Record Found
# Record 1824: Record Found
# Record 1825: Record Found
# Record 1826: Record Found
# Record 1827: Record Found
# Record 1828: Record Found
# Record 1829: Record Found
# Record 1830: Record Found
# Record 1831: Record Found
# Record 1832: Record Found
# Record 1833: Record Found
# Record 1834: Record Found
# Record 1835: Record Found
# Record 1836: Record Found
# Record 1837: Record Found
# Record 1838: Record Found
# Record 1839: Record Found
# Record 1840: Record Found
# Record 1841: Record Found
# Record 1842: Record Found
# Record 1843: Record Found
# Record 1844: Record Found
# Record 1845: Record Found
# Record 1846: Record Found
# Record 1847: Record Found
# Record 1848: Record Found
# Record 1849: Record Found
# Record 1850: Record Found
# Record 1851: Record Found
# Record 1852: Record Found
# Record 1853: Record Found
# Record 1854: Record Found
# Record 1855: Record Found
# Record 1856: Record Found
# Record 1857: Record Found
# Record 1858: Record Found
# Record 1859: Record Found
# Record 1860: Record Found
# Record 1861: Record Found
# Record 1862: Record Found
# Record 1863: Record Found
# Record 1864: Record Found
# Record 1865: Record Found
# Record 1866: Record Found
# Record 1867: Record Found
# Record 1868: Record Found
# Record 1869: Record Found
# Record 1870: Record Found
# Record 1871: Record Found
# Record 1872: Record Found
# Record 1873: Record Found
# Record 1874: Record Found
# Record 1875: Record Found
# Record 1876: Record Found
# Record 1877: Record Found
# Record 1878: Record Found
# Record 1879: Record Found
# Record 1880: Record Found
# Record 1881: Record Found
# Record 1882: Record Found
# Record 1883: Record Found
# Record 1884: Record Found
# Record 1885: Record Found
# Record 1886: Record Found
# Record 1887: Record Found
# Record 1888: Record Found
# Record 1889: Record Found
# Record 1890: Record Found
# Record 1891: Record Found
# Record 1892: Record Found
# Record 1893: Record Found
# Record 1894: Record Found
# Record 1895: Record Found
# Record 1896: Record Found
# Record 1897: Record Found
# Record 1898: Record Found
# Record 1899: Record Found
# Record 1900: Record Found
# Record 1901: Record Found
# Record 1902: Record Found
# Record 1903: Record Found
# Record 1904: Record Found
# Record 1905: Record Found
# Record 1906: Record Found
# Record 1907: Record Found
# Record 1908: Record Found
# Record 1909: Record Found
# Record 1910: Record Found
# Record 1911: Record Found
# Record 1912: Record Found
# Record 1913: Record Found
# Record 1914: Record Found
# Record 1915: Record Found
# Record 1916: Record Found
# Record 1917: Record Found
# Record 1918: Record Found
# Record 1919: Record Found
# Record 1920: Record Found
# Record 1921: Record Found
# Record 1922: Record Found
# Record 1923: Record Found
# Record 1924: Record Found
# Record 1925: Record Found
# Record 1926: Record Found
# Record 1927: Record Found
# Record 1928: Record Found
# Record 1929: Record Found
# Record 1930: Record Found
# Record 1931: Record Found
# Record 1932: Record Found
# Record 1933: Record Found
# Record 1934: Record Found
# Record 1935: Record Found
# Record 1936: Record Found
# Record 1937: Record Found
# Record 1938: Record Found
# Record 1939: Record Found
# Record 1940: Record Found
# Record 1941: Record Found
# Record 1942: Record Found
# Record 1943: Record Found
# Record 1944: Record Found
# Record 1945: Record Found
# Record 1946: Record Found
# Record 1947: Record Found
# Record 1948: Record Found
# Record 1949: Record Found
# Record 1950: Record Found
# Record 1951: Record Found
# Record 1952: Record Found
# Record 1953: Record Found
# Record 1954: Record Found
# Record 1955: Record Found
# Record 1956: Record Found
# Record 1957: Record Found
# Record 1958: Record Found
# Record 1959: Record Found
# Record 1960: Record Found
# Record 1961: Record Found
# Record 1962: Record Found
# Record 1963: Record Found
# Record 1964: Record Found
# Record 1965: Record Found
# Record 1966: Record Found
# Record 1967: Record Found
# ...
# Record 9387: Record Found
# Record 9388: Record Found
# Record 9389: Record Found
# Record 9390: Record Found
# Record 9391: Record Found
# Record 9392: Record Found
# Record 9393: Record Found
# Record 9394: Record Found
# Record 9395: Record Found
# Record 9396: Record Found
# Record 9397: Record Found
# Record 9398: Record Found
# Record 9399: Record Found
# Record 9400: Record Found
# Record 9401: Record Found
# Record 9402: Record Found
# Record 9403: Record Found
# Record 9404: Record Found
# Record 9405: Record Found
# Record 9406: Record Found
# Record 9407: Record Found
# Record 9408: Record Found
# Record 9409: Record Found
# Record 9410: Record Found
# Record 9411: Record Found
# Record 9412: Record Found
# Record 9413: Record Found
# Record 9414: Record Found
# Record 9415: Record Found
# Record 9416: Record Found
# Record 9417: Record Found
# Record 9418: Record Found
# Record 9419: Record Found
# Record 9420: Record Found
# Record 9421: Record Found
# Record 9422: Record Found
# Record 9423: Record Found
# Record 9424: Record Found
# Record 9425: Record Found
# Record 9426: Record Found
# Record 9427: Record Found
# Record 9428: Record Found
# Record 9429: Record Found
# Record 9430: Record Found
# Record 9431: Record Found
# Record 9432: Record Found
# Record 9433: Record Found
# Record 9434: Record Found
# Record 9435: Record Found
# Record 9436: Record Found
# Record 9437: Record Found
# Record 9438: Record Found
# Record 9439: Record Found
# Record 9440: Record Found
# Record 9441: Record Found
# Record 9442: Record Found
# Record 9443: Record Found
# Record 9444: Record Found
# Record 9445: Record Found
# Record 9446: Record Found
# Record 9447: Record Found
# Record 9448: Record Found
# Record 9449: Record Found
# Record 9450: Record Found
# Record 9451: Record Found
# Record 9452: Record Found
# Record 9453: Record Found
# Record 9454: Record Found
# Record 9455: Record Found
# Record 9456: Record Found
# Record 9457: Record Found
# Record 9458: Record Found
# Record 9459: Record Found
# Record 9460: Record Found
# Record 9461: Record Found
# Record 9462: Record Found
# Record 9463: Record Found
# Record 9464: Record Found
# Record 9465: Record Found
# Record 9466: Record Found
# Record 9467: Record Found
# Record 9468: Record Found
# Record 9469: Record Found
# Record 9470: Record Found
# Record 9471: Record Found
# Record 9472: Record Found
# Record 9473: Record Found
# Record 9474: Record Found
# Record 9475: Record Found
# Record 9476: Record Found
# Record 9477: Record Found
# Record 9478: Record Found
# Record 9479: Record Found
# Record 9480: Record Found
# Record 9481: Record Found
# Record 9482: Record Found
# Record 9483: Record Found
# Record 9484: Record Found
# Record 9485: Record Found
# Record 9486: Record Found
# Record 9487: Record Found
# Record 9488: Record Found
# Record 9489: Record Found
# Record 9490: Record Found
# Record 9491: Record Found
# Record 9492: Record Found
# Record 9493: Record Found
# Record 9494: Record Found
# Record 9495: Record Found
# Record 9496: Record Found
# Record 9497: Record Found
# Record 9498: Record Found
# Record 9499: Record Found
# Record 9500: Record Found
# Record 9501: Record Found
# Record 9502: Record Found
# Record 9503: Record Found
# Record 9504: Record Found
# Record 9505: Record Found
# Record 9506: Record Found
# Record 9507: Record Found
# Record 9508: Record Found
# Record 9509: Record Found
# Record 9510: Record Found
# Record 9511: Record Found
# Record 9512: Record Found
# Record 9513: Record Found
# Record 9514: Record Found
# Record 9515: Record Found
# Record 9516: Record Found
# Record 9517: Record Found
# Record 9518: Record Found
# Record 9519: Record Found
# Record 9520: Record Found
# Record 9521: Record Found
# Record 9522: Record Found
# Record 9523: Record Found
# Record 9524: Record Found
# Record 9525: Record Found
# Record 9526: Record Found
# Record 9527: Record Found
# Record 9528: Record Found
# Record 9529: Record Found
# Record 9530: Record Found
# Record 9531: Record Found
# Record 9532: Record Found
# Record 9533: Record Found
# Record 9534: Record Found
# Record 9535: Record Found
# Record 9536: Record Found
# Record 9537: Record Found
# Record 9538: Record Found
# Record 9539: Record Found
# Record 9540: Record Found
# Record 9541: Record Found
# Record 9542: Record Found
# Record 9543: Record Found
# Record 9544: Record Found
# Record 9545: Record Found
# Record 9546: Record Found
# Record 9547: Record Found
# Record 9548: Record Found
# Record 9549: Record Found
# Record 9550: Record Found
# Record 9551: Record Found
# Record 9552: Record Found
# Record 9553: Record Found
# Record 9554: Record Found
# Record 9555: Record Found
# Record 9556: Record Found
# Record 9557: Record Found
# Record 9558: Record Found
# Record 9559: Record Found
# Record 9560: Record Found
# Record 9561: Record Found
# Record 9562: Record Found
# Record 9563: Record Found
# Record 9564: Record Found
# Record 9565: Record Found
# Record 9566: Record Found
# Record 9567: Record Found
# Record 9568: Record Found
# Record 9569: Record Found
# Record 9570: Record Found
# Record 9571: Record Found
# Record 9572: Record Found
# Record 9573: Record Found
# Record 9574: Record Found
# Record 9575: Record Found
# Record 9576: Record Found
# Record 9577: Record Found
# Record 9578: Record Found
# Record 9579: Record Found
# Record 9580: Record Found
# Record 9581: Record Found
# Record 9582: Record Found
# Record 9583: Record Found
# Record 9584: Record Found
# Record 9585: Record Found
# Record 9586: Record Found
# Record 9587: Record Found
# Record 9588: Record Found
# Record 9589: Record Found
# Record 9590: Record Found
# Record 9591: Record Found
# Record 9592: Record Found
# Record 9593: Record Found
# Record 9594: Record Found
# Record 9595: Record Found
# Record 9596: Record Found
# Record 9597: Record Found
# Record 9598: Record Found
# Record 9599: Record Found
# Record 9600: Record Found
# Record 9601: Record Found
# Record 9602: Record Found
# Record 9603: Record Found
# Record 9604: Record Found
# Record 9605: Record Found
# Record 9606: Record Found
# Record 9607: Record Found
# Record 9608: Record Found
# Record 9609: Record Found
# Record 9610: Record Found
# Record 9611: Record Found
# Record 9612: Record Found
# Record 9613: Record Found
# Record 9614: Record Found
# Record 9615: Record Found
# Record 9616: Record Found
# Record 9617: Record Found
# Record 9618: Record Found
# Record 9619: Record Found
# Record 9620: Record Found
# Record 9621: Record Found
# Record 9622: Record Found
# Record 9623: Record Found
# Record 9624: Record Found
# Record 9625: Record Found
# Record 9626: Record Found
# Record 9627: Record Found
# Record 9628: Record Found
# Record 9629: Record Found
# Record 9630: Record Found
# Record 9631: Record Found
# Record 9632: Record Found
# Record 9633: Record Found
# Record 9634: Record Found
# Record 9635: Record Found
# Record 9636: Record Found
# Record 9637: Record Found
# Record 9638: Record Found
# Record 9639: Record Found
# Record 9640: Record Found
# Record 9641: Record Found
# Record 9642: Record Found
# Record 9643: Record Found
# Record 9644: Record Found
# Record 9645: Record Found
# Record 9646: Record Found
# Record 9647: Record Found
# Record 9648: Record Found
# Record 9649: Record Found
# Record 9650: Record Found
# Record 9651: Record Found
# Record 9652: Record Found
# Record 9653: Record Found
# Record 9654: Record Found
# Record 9655: Record Found
# Record 9656: Record Found
# Record 9657: Record Found
# Record 9658: Record Found
# Record 9659: Record Found
# Record 9660: Record Found
# Record 9661: Record Found
# Record 9662: Record Found
# Record 9663: Record Found
# Record 9664: Record Found
# Record 9665: Record Found
# Record 9666: Record Found
# Record 9667: Record Found
# Record 9668: Record Found
# Record 9669: Record Found
# Record 9670: Record Found
# Record 9671: Record Found
# Record 9672: Record Found
# Record 9673: Record Found
# Record 9674: Record Found
# Record 9675: Record Found
# Record 9676: Record Found
# Record 9677: Record Found
# Record 9678: Record Found
# Record 9679: Record Found
# Record 9680: Record Found
# Record 9681: Record Found
# Record 9682: Record Found
# Record 9683: Record Found
# Record 9684: Record Found
# Record 9685: Record Found
# Record 9686: Record Found
# Record 9687: Record Found
# Record 9688: Record Found
# Record 9689: Record Found
# Record 9690: Record Found
# Record 9691: Record Found
# Record 9692: Record Found
# Record 9693: Record Found
# Record 9694: Record Found
# Record 9695: Record Found
# Record 9696: Record Found
# Record 9697: Record Found
# Record 9698: Record Found
# Record 9699: Record Found
# Record 9700: Record Found
# Record 9701: Record Found
# Record 9702: Record Found
# Record 9703: Record Found
# Record 9704: Record Found
# Record 9705: Record Found
# Record 9706: Record Found
# Record 9707: Record Found
# Record 9708: Record Found
# Record 9709: Record Found
# Record 9710: Record Found
# Record 9711: Record Found
# Record 9712: Record Found
# Record 9713: Record Found
# Record 9714: Record Found
# Record 9715: Record Found
# Record 9716: Record Found
# Record 9717: Record Found
# Record 9718: Record Found
# Record 9719: Record Found
# Record 9720: Record Found
# Record 9721: Record Found
# Record 9722: Record Found
# Record 9723: Record Found
# Record 9724: Record Found
# Record 9725: Record Found
# Record 9726: Record Found
# Record 9727: Record Found
# Record 9728: Record Found
# Record 9729: Record Found
# Record 9730: Record Found
# Record 9731: Record Found
# Record 9732: Record Found
# Record 9733: Record Found
# Record 9734: Record Found
# Record 9735: Record Found
# Record 9736: Record Found
# Record 9737: Record Found
# Record 9738: Record Found
# Record 9739: Record Found
# Record 9740: Record Found
# Record 9741: Record Found
# Record 9742: Record Found
# Record 9743: Record Found
# Record 9744: Record Found
# Record 9745: Record Found
# Record 9746: Record Found
# Record 9747: Record Found
# Record 9748: Record Found
# Record 9749: Record Found
# Record 9750: Record Found
# Record 9751: Record Found
# Record 9752: Record Found
# Record 9753: Record Found
# Record 9754: Record Found
# Record 9755: Record Found
# Record 9756: Record Found
# Record 9757: Record Found
# Record 9758: Record Found
# Record 9759: Record Found
# Record 9760: Record Found
# Record 9761: Record Found
# Record 9762: Record Found
# Record 9763: Record Found
# Record 9764: Record Found
# Record 9765: Record Found
# Record 9766: Record Found
# Record 9767: Record Found
# Record 9768: Record Found
# Record 9769: Record Found
# Record 9770: Record Found
# Record 9771: Record Found
# Record 9772: Record Found
# Record 9773: Record Found
# Record 9774: Record Found
# Record 9775: Record Found
# Record 9776: Record Found
# Record 9777: Record Found
# Record 9778: Record Found
# Record 9779: Record Found
# Record 9780: Record Found
# Record 9781: Record Found
# Record 9782: Record Found
# Record 9783: Record Found
# Record 9784: Record Found
# Record 9785: Record Found
# Record 9786: Record Found
# Record 9787: Record Found
# Record 9788: Record Found
# Record 9789: Record Found
# Record 9790: Record Found
# Record 9791: Record Found
# Record 9792: Record Found
# Record 9793: Record Found
# Record 9794: Record Found
# Record 9795: Record Found
# Record 9796: Record Found
# Record 9797: Record Found
# Record 9798: Record Found
# Record 9799: Record Found
# Record 9800: Record Found
# Record 9801: Record Found
# Record 9802: Record Found
# Record 9803: Record Found
# Record 9804: Record Found
# Record 9805: Record Found
# Record 9806: Record Found
# Record 9807: Record Found
# Record 9808: Record Found
# Record 9809: Record Found
# Record 9810: Record Found
# Record 9811: Record Found
# Record 9812: Record Found
# Record 9813: Record Found
# Record 9814: Record Found
# Record 9815: Record Found
# Record 9816: Record Found
# Record 9817: Record Found
# Record 9818: Record Found
# Record 9819: Record Found
# Record 9820: Record Found
# Record 9821: Record Found
# Record 9822: Record Found
# Record 9823: Record Found
# Record 9824: Record Found
# Record 9825: Record Found
# Record 9826: Record Found
# Record 9827: Record Found
# Record 9828: Record Found
# Record 9829: Record Found
# Record 9830: Record Found
# Record 9831: Record Found
# Record 9832: Record Found
# Record 9833: Record Found
# Record 9834: Record Found
# Record 9835: Record Found
# Record 9836: Record Found
# Record 9837: Record Found
# Record 9838: Record Found
# Record 9839: Record Found
# Record 9840: Record Found
# Record 9841: Record Found
# Record 9842: Record Found
# Record 9843: Record Found
# Record 9844: Record Found
# Record 9845: Record Found
# Record 9846: Record Found
# Record 9847: Record Found
# Record 9848: Record Found
# Record 9849: Record Found
# Record 9850: Record Found
# Record 9851: Record Found
# Record 9852: Record Found
# Record 9853: Record Found
# Record 9854: Record Found
# Record 9855: Record Found
# Record 9856: Record Found
# Record 9857: Record Found
# Record 9858: Record Found
# Record 9859: Record Found
# Record 9860: Record Found
# Record 9861: Record Found
# Record 9862: Record Found
# Record 9863: Record Found
# Record 9864: Record Found
# Record 9865: Record Found
# Record 9866: Record Found
# Record 9867: Record Found
# Record 9868: Record Found
# Record 9869: Record Found
# Record 9870: Record Found
# Record 9871: Record Found
# Record 9872: Record Found
# Record 9873: Record Found
# Record 9874: Record Found
# Record 9875: Record Found
# Record 9876: Record Found
# Record 9877: Record Found
# Record 9878: Record Found
# Record 9879: Record Found
# Record 9880: Record Found
# Record 9881: Record Found
# Record 9882: Record Found
# Record 9883: Record Found
# Record 9884: Record Found
# Record 9885: Record Found
# Record 9886: Record Found
# Record 9887: Record Found
# Record 9888: Record Found
# Record 9889: Record Found
# Record 9890: Record Found
# Record 9891: Record Found
# Record 9892: Record Found
# Record 9893: Record Found
# Record 9894: Record Found
# Record 9895: Record Found
# Record 9896: Record Found
# Record 9897: Record Found
# Record 9898: Record Found
# Record 9899: Record Found
# Record 9900: Record Found
# Record 9901: Record Found
# Record 9902: Record Found
# Record 9903: Record Found
# Record 9904: Record Found
# Record 9905: Record Found
# Record 9906: Record Found
# Record 9907: Record Found
# Record 9908: Record Found
# Record 9909: Record Found
# Record 9910: Record Found
# Record 9911: Record Found
# Record 9912: Record Found
# Record 9913: Record Found
# Record 9914: Record Found
# Record 9915: Record Found
# Record 9916: Record Found
# Record 9917: Record Found
# Record 9918: Record Found
# Record 9919: Record Found
# Record 9920: Record Found
# Record 9921: Record Found
# Record 9922: Record Found
# Record 9923: Record Found
# Record 9924: Record Found
# Record 9925: Record Found
# Record 9926: Record Found
# Record 9927: Record Found
# Record 9928: Record Found
# Record 9929: Record Found
# Record 9930: Record Found
# Record 9931: Record Found
# Record 9932: Record Found
# Record 9933: Record Found
# Record 9934: Record Found
# Record 9935: Record Found
# Record 9936: Record Found
# Record 9937: Record Found
# Record 9938: Record Found
# Record 9939: Record Found
# Record 9940: Record Found
# Record 9941: Record Found
# Record 9942: Record Found
# Record 9943: Record Found
# Record 9944: Record Found
# Record 9945: Record Found
# Record 9946: Record Found
# Record 9947: Record Found
# Record 9948: Record Found
# Record 9949: Record Found
# Record 9950: Record Found
# Record 9951: Record Found
# Record 9952: Record Found
# Record 9953: Record Found
# Record 9954: Record Found
# Record 9955: Record Found
# Record 9956: Record Found
# Record 9957: Record Found
# Record 9958: Record Found
# Record 9959: Record Found
# Record 9960: Record Found
# Record 9961: Record Found
# Record 9962: Record Found
# Record 9963: Record Found
# Record 9964: Record Found
# Record 9965: Record Found
# Record 9966: Record Found
# Record 9967: Record Found
# Record 9968: Record Found
# Record 9969: Record Found
# Record 9970: Record Found
# Record 9971: Record Found
# Record 9972: Record Found
# Record 9973: Record Found
# Record 9974: Record Found
# Record 9975: Record Found
# Record 9976: Record Found
# Record 9977: Record Found
# Record 9978: Record Found
# Record 9979: Record Found
# Record 9980: Record Found
# Record 9981: Record Found
# Record 9982: Record Found
# Record 9983: Record Found
# Record 9984: Record Found
# Record 9985: Record Found
# Record 9986: Record Found
# Record 9987: Record Found
# Record 9988: Record Found
# Record 9989: Record Found
# Record 9990: Record Found
# Record 9991: Record Found
# Record 9992: Record Found
# Record 9993: Record Found
# Record 9994: Record Found
# Record 9995: Record Found
# Record 9996: Record Found
# Record 9997: Record Found
# Record 9998: Record Found
# Record 9999: Record Found
# Record 10000: Record Found
# Completed

# %%
#data_f[data_f['CNIC'] == 4130351972391]

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import os
from selenium.webdriver.support.ui import Select
import time
import csv
from csv import DictWriter
from collections import OrderedDict
import xlsxwriter
import dask.dataframe as dd

col_sg  = ["SCH_ID", "SCH_NAME","STATUS"]
col_mm = ["School_ID","School_SEMIS_Code","School_Name","Active_Ind"']
dict = {}

data_f = pd.read_excel(r'E:/DGME/MNE_Schools.csv', usecols = columns, low_memory=False)

# %%
data_f = pd.DataFrame(data_f)
data_f = data_f.loc[data_f['Active_ind']=='TRUE']
data_f = data_f[1100:1500]
                
url = "http://checker.sindheducation.gov.pk/CheckBiometrics.aspx"

# create a new Chrome session
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(5)


# Search DDL
search_ddl = driver.find_element_by_id("ContentPlaceHolder1_ddlSearchBy")
select = Select(search_ddl)
select.select_by_index(1)
time.sleep(4)
data = True
i = 0
for index, row in data_f.iterrows():
    search_text = driver.find_element_by_id("ContentPlaceHolder1_txtSearch")
    search_text.click()
    search_text.clear()
    search_text.send_keys(row['CNIC'])
    search_text.send_keys(Keys.ENTER)
    time.sleep(1)
    search_button = driver.find_element_by_id("ContentPlaceHolder1_btn_search")
    search_button.click()
    time.sleep(6)

    try:
        data_set = driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[15]')
        dict[column_name[0]] = row['CNIC']
        dict[column_name[1]] = data_set.get_attribute('innerText')
        print("Record " + str(i) + ": Matched")
        # data = True
    except:
        dict[column_name[0]] = row['CNIC']
        dict[column_name[1]] = 'Unmatched'
        print("Record " + str(i) + ": Not Found/Unmatched")
        # data = False
        # break
     
    with open(r'D:\Status_ActiveIndicators_Complete.csv', 'a', newline='') as f_object:
        dictwriter_object = csv.DictWriter(f_object, fieldnames=column_name)
        if index == 0:
            dictwriter_object.writeheader()
        dictwriter_object.writerow(dict)
        dict.clear()
    i = i + 1;
driver.quit();
print("Completed")

# %% [markdown]
# ## Fetch All Records from Table

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import os
from selenium.webdriver.support.ui import Select
import time
import csv
from csv import DictWriter
from collections import OrderedDict
import xlsxwriter
import dask.dataframe as dd
import numpy as np

column_name = ["SEMIS ID", "SEMIS ID (DC)", "SEMIS ID (M&E)", "Status"]

dict = {}

# %%
col_mm = ["School_SEMIS_Code", "School_Name", "Active_Ind"]
data_mm = pd.read_excel(r'E:/DGME/work/MNE_Schools.xlsx', usecols = col_mm , sheet_name="sheet")

data_mm = pd.DataFrame(data_mm)
data_mm = data_mm.loc[data_mm['Active_Ind']==1]
#data_mm = data_mm[0:100]

data_mm['School_SEMIS_Code'] = data_mm['School_SEMIS_Code'].astype(np.int64)
data_mm['Active_Ind'] = data_mm['Active_Ind'].astype(np.int64())
print(data_mm['School_SEMIS_Code'].dtype, data_mm['Active_Ind'].dtype)

data_mm.head()

# %%
df_mm = data_mm[3000 :5000]
df_mm

# %%
url = "http://checker.sindheducation.gov.pk/CheckBiometrics.aspx"

# create a new Chrome session
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(5)


# Search DDL
search_ddl = driver.find_element_by_id("ContentPlaceHolder1_ddlSearchBy")
select = Select(search_ddl)
select.select_by_index(2)
time.sleep(4)
data = True
i = 1
for index, row in df_mm.iterrows():
    for j in range(3):        
        search_text = driver.find_element_by_id("ContentPlaceHolder1_txtSearch")
        search_text.click()
        search_text.clear()
        search_text.send_keys(row['School_SEMIS_Code'])
        search_text.send_keys(Keys.ENTER)
        time.sleep(1)
        search_button = driver.find_element_by_id("ContentPlaceHolder1_btn_search")
        search_button.click()
        time.sleep(6)
        break 

    try:
        data_set = driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[15]')
        semid_dc =  driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[9]')
        semid_me =  driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[12]')
        semid_sg = semid_dc.get_attribute('innerText')
        semid_mm = semid_me.get_attribute('innerText')
        
        #if (semid_dc == semid_me ):
            
        dict[column_name[0]] = row['School_SEMIS_Code']
        dict[column_name[1]] = semid_sg
        dict[column_name[2]] = semid_mm
        dict[column_name[3]] = data_set.get_attribute('innerText')
        print("Record " + str(i) + ": Record Found")
        # data = True
    except:
        dict[column_name[0]] = row['School_SEMIS_Code']
        dict[column_name[3]] = 'Not Found'
        print("Record " + str(i) + ": Not Found")
        # data = False
        # break
    driver.implicitly_wait(3)
    with open(r'D:\SchoolsRecordSet_Status\Status_ActiveSchool_Recordset.csv', 'a', newline='') as f_object:
        dictwriter_object = csv.DictWriter(f_object, fieldnames=column_name)
        if index == 0:
            dictwriter_object.writeheader()
        dictwriter_object.writerow(dict)
        dict.clear()
    i = i + 1;
    
driver.quit();
print("Completed")
