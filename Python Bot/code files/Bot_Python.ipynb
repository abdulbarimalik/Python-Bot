# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
import pandas as pd
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import re
import os
from selenium.webdriver.support.ui import Select
import time
import csv
from csv import DictWriter
from collections import OrderedDict
import xlsxwriter
import dask.dataframe as dd

column_name = ["CNIC", "Status"]
columns = ["CNIC", "Active_ind","Cadre"]
dict = {}

data_f = pd.read_csv(r'E:/DGME/allteachers.csv', usecols = columns, low_memory=False)

# %%
data_f = pd.DataFrame(data_f)
data_f = data_f.loc[data_f['Active_ind']=='TRUE']
data_f = data_f[0:100]
                
url = "http://checker.sindheducation.gov.pk/CheckBiometrics.aspx"

# create a new Chrome session
driver = webdriver.Chrome(ChromeDriverManager().install())
driver.get(url)
driver.implicitly_wait(5)


# Search DDL
search_ddl = driver.find_element_by_id("ContentPlaceHolder1_ddlSearchBy")
select = Select(search_ddl)
select.select_by_index(1)
time.sleep(4)
data = True
i = 0
for index, row in data_f.iterrows():
    search_text = driver.find_element_by_id("ContentPlaceHolder1_txtSearch")
    search_text.click()
    search_text.clear()
    search_text.send_keys(row['CNIC'])
    search_text.send_keys(Keys.ENTER)
    time.sleep(1)
    search_button = driver.find_element_by_id("ContentPlaceHolder1_btn_search")
    search_button.click()
    time.sleep(6)

    try:
        data_set = driver.find_element_by_xpath(
            '//*[@id="ContentPlaceHolder1_gvDCDetails"]/tbody/tr[2]/td[15]')
        dict[column_name[0]] = row['CNIC']
        dict[column_name[1]] = data_set.get_attribute('innerText')
        print("Record " + str(i) + ": Matched")
        # data = True
    except:
        dict[column_name[0]] = row['CNIC']
        dict[column_name[1]] = 'Unmatched'
        print("Record " + str(i) + ": Not Found/Unmatched")
        # data = False
        # break
     
    with open(r'D:\Status_ActiveIndicators.csv', 'a', newline='') as f_object:
        dictwriter_object = csv.DictWriter(f_object, fieldnames=column_name)
        if index == 0:
            dictwriter_object.writeheader()
        dictwriter_object.writerow(dict)
        dict.clear()
    i = i + 1;
driver.quit();
print("Completed")
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 89.0.4389
# [WDM] - Get LATEST driver version for 89.0.4389
# [WDM] - Driver [C:\Users\Dell\.wdm\drivers\chromedriver\win32\89.0.4389.23\chromedriver.exe] found in cache
# Record 0: Matched
# Record 1: Matched
# Record 2: Matched
# Record 3: Matched
# Record 4: Matched
# Record 5: Matched
# Record 6: Matched
# Record 7: Matched
# Record 8: Matched
# Record 9: Matched
# Record 10: Matched
# Record 11: Not Found/Unmatched
# Record 12: Matched
# Record 13: Matched
# Record 14: Matched
# Record 15: Matched
# Record 16: Matched
# Record 17: Matched
# Record 18: Matched
# Record 19: Matched
# Record 20: Matched
# Record 21: Matched
# Record 22: Matched
# Record 23: Matched
# Record 24: Matched
# Record 25: Matched
# Record 26: Matched
# Record 27: Matched
# Record 28: Matched
# Record 29: Matched
# Record 30: Matched
# Record 31: Matched
# Record 32: Matched
# Record 33: Matched
# Record 34: Matched
# Record 35: Matched
# Record 36: Matched
# Record 37: Matched
# Record 38: Matched
# Record 39: Matched
# Record 40: Matched
# Record 41: Matched
# Record 42: Matched
# Record 43: Matched
# Record 44: Matched
# Record 45: Matched
# Record 46: Matched
# Record 47: Matched
# Record 48: Matched
# Record 49: Matched
# Record 50: Matched
# Record 51: Matched
# Record 52: Matched
# Record 53: Matched
# Record 54: Matched
# Record 55: Matched
# Record 56: Matched
# Record 57: Matched
# Record 58: Matched
# Record 59: Matched
# Record 60: Matched
# Record 61: Matched
# Record 62: Matched
# Record 63: Matched
# Record 64: Matched
# Record 65: Matched
# Record 66: Matched
# Record 67: Matched
# Record 68: Not Found/Unmatched
# Record 69: Matched
# Record 70: Not Found/Unmatched
# Record 71: Matched
# Record 72: Matched
# Record 73: Matched
# Record 74: Not Found/Unmatched
# Record 75: Matched
# Record 76: Matched
# Record 77: Matched
# Record 78: Matched
# Record 79: Matched
# Record 80: Matched
# Record 81: Matched
# Record 82: Matched
# Record 83: Matched
# Record 84: Matched
# Record 85: Matched
# Record 86: Matched
# Record 87: Matched
# Record 88: Matched
# Record 89: Not Found/Unmatched
# Record 90: Not Found/Unmatched
# Record 91: Matched
# Record 92: Not Found/Unmatched
# Record 93: Not Found/Unmatched
# Record 94: Matched
# Record 95: Not Found/Unmatched
# Record 96: Not Found/Unmatched
# Record 97: Matched
# Record 98: Matched
# Record 99: Matched
# Completed
