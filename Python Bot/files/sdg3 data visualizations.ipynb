# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %%
sba = pd.read_excel('E:/3.1.2.xlsx', sheet_name = 'Sheet1')
sba = pd.DataFrame(sba)
sba
# Out:
#     Year  National  P_Year  Punjab  Sindh   KPK  Balochistan  Milestones
# 0   2000        23     NaN     NaN    NaN   NaN          NaN         NaN
# 1   2004        31  2004.0    33.0   38.0  26.0         14.0         NaN
# 2   2005        48     NaN     NaN    NaN   NaN          NaN         NaN
# 3   2006        33  2006.0    32.0   41.0  27.0         15.0         NaN
# 4   2007        40  2007.0    43.0    NaN   NaN          NaN         NaN
# 5   2008        41  2008.0    43.0   42.0  32.0         17.0         NaN
# 6   2010        43  2010.0    44.0   49.0  37.0         29.0         NaN
# 7   2011        51  2011.0    35.0    NaN   NaN          NaN         NaN
# 8   2012        55  2012.0    56.0   53.0  49.0         35.0         NaN
# 9   2013        58     NaN     NaN    NaN   NaN          NaN         NaN
# 10  2014        59  2014.0    65.0   59.0  56.0         39.0         NaN
# 11  2017        63  2017.0    76.0   75.0  68.0         38.0         NaN
# ...

# %%
sba_p = pd.read_excel('E:/3.1.2.xlsx', sheet_name = 'Sheet2')
sba_p = pd.DataFrame(sba_p)
sba_p
# Out:
#    P_Year  Punjab
# 0    2004      33
# 1    2006      32
# 2    2007      43
# 3    2008      43
# 4    2010      44
# 5    2011      35
# 6    2012      56
# 7    2014      65
# 8    2017      76

# %%
sba_s = pd.read_excel('E:/3.1.2.xlsx', sheet_name = 'Sheet3')
sba_s = pd.DataFrame(sba_s)
sba_s
sba_k = pd.read_excel('E:/3.1.2.xlsx', sheet_name = 'Sheet4')
sba_k = pd.DataFrame(sba_k)
sba_k
sba_b = pd.read_excel('E:/3.1.2.xlsx', sheet_name = 'Sheet5')
sba_b = pd.DataFrame(sba_b)
sba_b
# Out:
#    Year  Balochistan
# 0  2004           14
# 1  2006           15
# 2  2008           17
# 3  2010           29
# 4  2012           35
# 5  2014           39
# 6  2017           38

# %%
fig = plt.figure(figsize= (20,15))
#axs = plt.subplots(1, 2)
ax1 = plt.subplot(221)
#ax1.plot_date(y= pred_c,x= prediction_dates,linestyle ='dashed',color = 'c' , label = 'Confirmed Forecast');
n_p = ax1.plot(sba['Year'],sba['National'],linestyle = '-',color = 'teal' , marker='o', label = 'National');
ax1.set_title("Skill Birth Attendance (%)" , fontsize = 15)
#ax1.set_xticklabels(sba['Year'],rotation=360)
#ax1.set_xlabel("",fontsize = 13) 
#ax1.set_ylabel('Percentage',fontsize = 13) 
ax1.legend()
ax2 = plt.subplot(222)
#ax1.plot_date(y= pred_c,x= prediction_dates,linestyle ='dashed',color = 'c' , label = 'Confirmed Forecast');
n_p = ax2.plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = 'green' , marker='o', label = 'Punjab');
ax2.set_title("Skill Birth Attendance (%)" , fontsize = 15)
#ax1.set_xticklabels(sba['Year'],rotation=360)
#ax1.set_xlabel("",fontsize = 13) 
#ax1.set_ylabel('Percentage',fontsize = 13) 
ax2.legend()
plt.show()

# %%
#axs = plt.subplots(1, 2)
fig, (ax1, ax2) = plt.subplots(2)
fig = plt.figure(figsize= (20,15))
#ax1 = plt.subplot(221)

n_p = ax1.plot(sba['Year'],sba['National'],linestyle = '-',color = 'teal' , marker='o', label = 'National');
#ax1.set_title("Skill Birth Attendance (%)" , fontsize = 15)

ax1.legend()
#ax2 = plt.subplot(222)

n_p = ax2.plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = 'green' , marker='o', label = 'Punjab');
#ax2.set_title("Skill Birth Attendance (%)" , fontsize = 15)

ax2.legend()
plt.show()

# %%
# fig = plt.figure(figsize= (20,15))
# #axs = plt.subplots(1, 2)
# ax1 = plt.subplot(221)
# #ax1.plot_date(y= pred_c,x= prediction_dates,linestyle ='dashed',color = 'c' , label = 'Confirmed Forecast');
# ax1.plot(sba['Year'],sba['National'],linestyle = '-',color = 'teal' , marker='o', label = 'National'); 
# ax1.legend()
# ax2 = plt.subplots(2, 2)
# #axs[0, 0].plot(x, y)
# #ax1.plot_date(y= pred_c,x= prediction_dates,linestyle ='dashed',color = 'c' , label = 'Confirmed Forecast');
# ax2[0,0].plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = 'green' , marker='o', label = 'Punjab');
# ax2[0,0].legend()
# plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(20, 10))

axs[0,0].plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = '#009688' , marker='o', label = 'Punjab');
axs[0,0].legend()
#axs[0, 0].set_title('Axis [0,0]')
axs[0, 1].plot(sba_s['Year'],sba_s['Sindh'],linestyle = '-',color = '#00e676' , marker='D', label = 'Sindh');
axs[0,1].legend()
#axs[0, 1].set_title('Axis [0,1]')
axs[1, 0].plot(sba_s['Year'],sba_k['Kpk'],linestyle = '-',color = '#007bff' , marker='s', label = 'KPK');
axs[1,0].legend()#c0ca33
#axs[1, 0].set_title('Axis [1,0]')
axs[1, 1].plot(sba_s['Year'],sba_b['Balochistan'],linestyle = '-',color = '#c0ca33' , marker='8', label = 'Balochistan');
axs[1,1].legend()
#axs[1, 1].set_title('Axis [1,1]')

# %%
a1 = plt.subplot2grid((3,3),(0,0),colspan = 2)
a2 = plt.subplot2grid((3,3),(0,2), rowspan = 3)
a3 = plt.subplot2grid((3,3),(1,0),rowspan = 2, colspan = 2)

# %%
fig, axs = plt.subplots(2, 3, figsize=(20, 10))

axs[0,0].plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = '#009688' , marker='o', label = 'Punjab');
axs[0,0].legend()
#axs[0, 0].set_title('Axis [0,0]')
axs[0, 1].plot(sba_s['Year'],sba_s['Sindh'],linestyle = '-',color = '#00e676' , marker='D', label = 'Sindh');
axs[0,1].legend()
#axs[0, 1].set_title('Axis [0,1]')
axs[1, 0].plot(sba_s['Year'],sba_k['Kpk'],linestyle = '-',color = '#007bff' , marker='s', label = 'KPK');
axs[1,0].legend()#c0ca33
#axs[1, 0].set_title('Axis [1,0]')
axs[1, 1].plot(sba_s['Year'],sba_b['Balochistan'],linestyle = '-',color = '#c0ca33' , marker='8', label = 'Balochistan');
axs[1,1].legend()

axs[0, 2].plot(sba['Year'], sba['National'],linestyle = '-',color = '#28a745' , marker='o', label = 'National')
axs[0, 2].legend()

# %%
fig, axs = plt.subplots(2, 3, figsize=(20, 5))
a1 = plt.subplot2grid((2,3),(0,0),rowspan = 2)
a2 = plt.subplot2grid((2,3),(0,1))
a3 = plt.subplot2grid((2,3),(0,2))
a4 = plt.subplot2grid((2,3),(1,1))
a5 = plt.subplot2grid((2,3),(1,2))

a1.plot(sba['Year'], sba['National'],linestyle = '-',color = '#28a745' , marker='o', label = 'National')
#a1.plot(sba['Year'], sba['Milestone'], linestyle='--', color = '#c0ca33', marker = 'D', label = 'Milestones')
a1.grid()
a1.legend()

a2.plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = '#009688' , marker='o', label = 'Punjab');
a2.grid()
a2.legend()
#axs[0, 0].set_title('Axis [0,0]')
a3.plot(sba_s['Year'],sba_s['Sindh'],linestyle = '-',color = '#00e676' , marker='D', label = 'Sindh');
a3.grid()
a3.legend()
#axs[0, 1].set_title('Axis [0,1]')
a4.plot(sba_s['Year'],sba_k['Kpk'],linestyle = '-',color = '#007bff' , marker='s', label = 'KPK');
a4.grid()
a4.legend()#c0ca33
#axs[1, 0].set_title('Axis [1,0]')
a5.plot(sba_s['Year'],sba_b['Balochistan'],linestyle = '-',color = '#c0ca33' , marker='8', label = 'Balochistan');
a5.grid()
a5.legend()

plt.show()

# %%
sba_m = pd.read_excel('E:/3.1.2.xlsx', sheet_name = 'Sheet6')
sba_m = pd.DataFrame(sba_m)
sba_m
# Out:
#    Year  Milestones
# 0  2018          71
# 1  2020          76
# 2  2022          77
# 3  2024          78
# 4  2026          79
# 5  2028          80
# 6  2030          95

# %%
fig, axs = plt.subplots(2, 3, figsize=(20, 5))
a1 = plt.subplot2grid((2,3),(0,0),rowspan = 2)
a2 = plt.subplot2grid((2,3),(0,1))
a3 = plt.subplot2grid((2,3),(0,2))
a4 = plt.subplot2grid((2,3),(1,1))
a5 = plt.subplot2grid((2,3),(1,2))

a1.plot(sba['Year'], sba['National'],linestyle = '-',color = '#28a745' , marker='o', label = 'National')
a1.plot(sba_m['Year'], sba_m['Milestones'], linestyle='--', color = '#c0ca33', marker = 'D', label = 'Milestones')
a1.grid()
a1.legend()

a2.plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = '#009688' , marker='o', label = 'Punjab');
a2.grid()
a2.legend()
#axs[0, 0].set_title('Axis [0,0]')
a3.plot(sba_s['Year'],sba_s['Sindh'],linestyle = '-',color = '#00e676' , marker='D', label = 'Sindh');
a3.grid()
a3.legend()
#axs[0, 1].set_title('Axis [0,1]')
a4.plot(sba_s['Year'],sba_k['Kpk'],linestyle = '-',color = '#007bff' , marker='s', label = 'KPK');
a4.grid()
a4.legend()#c0ca33
#axs[1, 0].set_title('Axis [1,0]')
a5.plot(sba_s['Year'],sba_b['Balochistan'],linestyle = '-',color = '#c0ca33' , marker='8', label = 'Balochistan');
a5.grid()
a5.legend()

plt.show()

# %%
sba_t = pd.read_excel('E:/3.1.2.xlsx', sheet_name = 'Sheet7')
sba_t = pd.DataFrame(sba_t)
sba_t
# Out:
#    Year  Target
# 0  2030      95

# %%
import matplotlib.image as image
# # constant
# dpi = 72
# # read in our png file
# im = image.imread('smile.png')
# image_size = im.shape[1], im.shape[0]


fig, axs = plt.subplots(2, 3, figsize=(20, 5))
a1 = plt.subplot2grid((2,3),(0,0),rowspan = 2)
a2 = plt.subplot2grid((2,3),(0,1))
a3 = plt.subplot2grid((2,3),(0,2))
a4 = plt.subplot2grid((2,3),(1,1))
a5 = plt.subplot2grid((2,3),(1,2))

a1.plot(sba['Year'], sba['National'],linestyle = '-',color = '#28a745' , marker='o', label = 'National')
a1.plot(sba_m['Year'], sba_m['Milestones'], linestyle='--', color = '#c0ca33', marker = 'D', label = 'Milestones')
a1.grid()
a1.set_title("Skill Birth Attendance(%)", fontsize = 10)
a1.legend()

a2.plot(sba_p['P_Year'],sba_p['Punjab'],linestyle = '-',color = '#009688' , marker='o', label = 'Punjab');
a2.grid()
a2.legend()

a3.plot(sba_s['Year'],sba_s['Sindh'],linestyle = '-',color = '#00e676' , marker='D', label = 'Sindh');
a3.grid()
a3.legend()

a4.plot(sba_s['Year'],sba_k['Kpk'],linestyle = '-',color = '#007bff' , marker='s', label = 'KPK');
a4.grid()
a4.legend()

a5.plot(sba_s['Year'],sba_b['Balochistan'],linestyle = '-',color = '#c0ca33' , marker='8', label = 'Balochistan');
a5.grid()
a5.legend()


plt.show()

# %%
sba_rn = pd.read_excel('E:/3.1.2 UR.xlsx', sheet_name = 'Sheet1')
sba_rn = pd.DataFrame(sba_rn)
sba_rn
sba_rp = pd.read_excel('E:/3.1.2 UR.xlsx', sheet_name = 'Sheet2')
sba_rp = pd.DataFrame(sba_rp)
sba_rp
sba_rs = pd.read_excel('E:/3.1.2 UR.xlsx', sheet_name = 'Sheet3')
sba_rs = pd.DataFrame(sba_rs)
sba_rs
sba_rk = pd.read_excel('E:/3.1.2 UR.xlsx', sheet_name = 'Sheet4')
sba_rk = pd.DataFrame(sba_rk)
sba_rk
sba_rb = pd.read_excel('E:/3.1.2 UR.xlsx', sheet_name = 'Sheet5')
sba_rb = pd.DataFrame(sba_rb)
sba_rb
# Out:
#    Year  Urban  Rural
# 0  2004     28      9
# 1  2006     28     10
# 2  2008     40     12
# 3  2010     54     21
# 4  2012     55     29
# 5  2014     58     31
# 6  2017     59     29

# %%
import matplotlib.image as image
# # constant
# dpi = 72
# # read in our png file
# im = image.imread('smile.png')
# image_size = im.shape[1], im.shape[0]


fig, axs = plt.subplots(2, 3, figsize=(20, 5))
a1 = plt.subplot2grid((2,3),(0,0),rowspan = 2)
a2 = plt.subplot2grid((2,3),(0,1))
a3 = plt.subplot2grid((2,3),(0,2))
a4 = plt.subplot2grid((2,3),(1,1))
a5 = plt.subplot2grid((2,3),(1,2))

a1.plot(sba_rn['Year'],sba_rn['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a1.plot(sba_rn['Year'],sba_rn['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a1.grid()
a1.set_ylabel('National')
a1.set_title("Skill Birth Attendance(%)", fontsize = 10)
a1.legend()

a2.plot(sba_rp['Year'],sba_rp['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a2.plot(sba_rp['Year'],sba_rp['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a2.grid()
a2.set_ylabel('Punjab')
a2.legend()

a3.plot(sba_rs['Year'],sba_rs['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a3.plot(sba_rs['Year'],sba_rs['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a3.grid()
a3.set_ylabel('Sindh')
a3.legend()

a4.plot(sba_rk['Year'],sba_rk['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a4.plot(sba_rk['Year'],sba_rk['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a4.grid()
a4.set_ylabel('Kpk')
a4.legend()

a5.plot(sba_rb['Year'],sba_rb['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a5.plot(sba_rb['Year'],sba_rb['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a5.grid()
a5.set_ylabel('Balochistan')
a5.legend()
# a5.plot(sba_s['Year'],sba_b['Balochistan'],linestyle = '-',color = '#c0ca33' , marker='8', label = 'Balochistan');
# a5.grid()
# a5.legend()


plt.show()

# %%
fig, axs = plt.subplots(3, 2, figsize=(12, 7))
a1 = plt.subplot2grid((3,2),(0,0),colspan = 2)
a2 = plt.subplot2grid((3,2),(1,0))
a3 = plt.subplot2grid((3,2),(1,1))
a4 = plt.subplot2grid((3,2),(2,0))
a5 = plt.subplot2grid((3,2),(2,1))

a1.plot(sba_rn['Year'],sba_rn['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a1.plot(sba_rn['Year'],sba_rn['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a1.grid()
a1.set_ylabel('National')
a1.set_title("Skill Birth Attendance(%)", fontsize = 10)
a1.legend()

a2.plot(sba_rp['Year'],sba_rp['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a2.plot(sba_rp['Year'],sba_rp['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a2.grid()
a2.set_ylabel('Punjab')
a2.legend()

a3.plot(sba_rs['Year'],sba_rs['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a3.plot(sba_rs['Year'],sba_rs['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a3.grid()
a3.set_ylabel('Sindh')
a3.legend()

a4.plot(sba_rk['Year'],sba_rk['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a4.plot(sba_rk['Year'],sba_rk['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a4.grid()
a4.set_ylabel('Kpk')
a4.legend()

a5.plot(sba_rb['Year'],sba_rb['Urban'],linestyle = '-',color = '#c0ca33' , marker='o', label = 'Rural');
a5.plot(sba_rb['Year'],sba_rb['Rural'],linestyle = '-',color = '#009688' , marker='D', label = 'Urban');
a5.grid()
a5.set_ylabel('Balochistan')
a5.legend()
# a5.plot(sba_s['Year'],sba_b['Balochistan'],linestyle = '-',color = '#c0ca33' , marker='8', label = 'Balochistan');
# a5.grid()
# a5.legend()


plt.show()
