# %%
import pandas as pd

# %%
file = pd.read_spss("E:/PDHS/PDHS 2017-18/2017-18/2017-18/SPSS/PK_2017-18_DHS_02252019_1144_45473/PKBR71SV/PKBR71FL.SAV")
phds_17 = pd.DataFrame(file)

# %%
phds_17
# Out:
#                 CASEID  BIDX V000   V001  V002  V003   V004      V005  V006  \
# 0             1   1  2   1.0  PK7    1.0   1.0   2.0    1.0  868683.0   2.0
# 1             1   1  2   2.0  PK7    1.0   1.0   2.0    1.0  868683.0   2.0
# 2             1   1  2   3.0  PK7    1.0   1.0   2.0    1.0  868683.0   2.0
# 3             1   1  2   4.0  PK7    1.0   1.0   2.0    1.0  868683.0   2.0
# 4             1   1  2   5.0  PK7    1.0   1.0   2.0    1.0  868683.0   2.0
# ...                ...   ...  ...    ...   ...   ...    ...       ...   ...
# 50490       580  26  2   3.0  PK7  580.0  26.0   2.0  580.0       0.0   2.0
# 50491       580  28  3   1.0  PK7  580.0  28.0   3.0  580.0       0.0   2.0
# 50492       580  28  3   2.0  PK7  580.0  28.0   3.0  580.0       0.0   2.0
# 50493       580  28  3   3.0  PK7  580.0  28.0   3.0  580.0       0.0   2.0
# 50494       580  28  3   4.0  PK7  580.0  28.0   3.0  580.0       0.0   2.0
#
# ...

# %%
phds_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50495 entries, 0 to 50494
# Columns: 1186 entries, CASEID to S469A
# dtypes: category(1087), float64(97), object(2)
# memory usage: 93.9+ MB

# %%
phds_17.describe()
# Out:
#                BIDX          V001          V002          V003          V004  \
# count  50495.000000  50495.000000  50495.000000  50495.000000  50495.000000
# mean       3.101733    283.896802     14.276819      2.969244    283.896802
# std        2.054793    165.248141      8.083951      2.741223    165.248141
# min        1.000000      1.000000      1.000000      1.000000      1.000000
# 25%        1.000000    141.000000      7.000000      2.000000    141.000000
# 50%        3.000000    279.000000     14.000000      2.000000    279.000000
# 75%        4.000000    414.000000     21.000000      3.000000    414.000000
# max       15.000000    580.000000     29.000000     40.000000    580.000000
#
#                V005          V006          V007          V008         V008A  \
# count  5.049500e+04  50495.000000  50495.000000  50495.000000  50495.000000
# mean   8.086081e+05      4.808555   2017.702565   1417.239331  43122.697317
# ...
