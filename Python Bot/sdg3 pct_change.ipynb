# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# file2 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='immunization')
# #df2 = pd.DataFrame(file2)
# df2= pd.DataFrame(file2).reset_index(drop='True')
# df2['progress_change'] = df2['Progress'].diff()
# df2['pct_change'] = df2['Progress'].pct_change()*100
# df2.fillna(0)

# %%
def autolabel(rects):
    """Attach a text label above each bar , displaying its height."""
    for rect in rects:
        height = rect.get_height()
        #plt.text(rect.get_x() + rect.get_width()/2.0, height, '%d' % int(height), ha='center', va='bottom') 
        plt.annotate('{}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 7),  # 4 points vertical offset
                    textcoords="offset points",
                    ha='center', size = 15, color='black')

# %%
def autolabel_line(xs, ys):
    for x,y in zip(xs,ys):
        label = "{:.2f}".format(y)
        plt.annotate(label, # this is the text
                 (x,y), # this is the point to label,    
                 textcoords="offset points", # how to position the text
                 xytext=(0,10), # distance from text to points (x,y)
                 ha='center', size = 14, color='black') # horizontal alignment can be left, right or center

# %%
def change_width(ax, new_value, bar) :
    for patch in bar.patches :
        current_width = patch.get_width()
        diff = current_width - new_value

        # we change the bar width
        patch.set_width(new_value)

        # we recenter the bar
        patch.set_x(patch.get_x() + diff * .5)

# %%
# import matplotlib.pyplot as plt2

# fig, ax1 = plt2.subplots(figsize=(20, 10))

# color = ['tab:blue', 'tab:orange', 'tab:red']
# #ax1.set_xlabel('Year')
# ax1.set_ylabel('Percentage', color='black', size=15)
# ax1.set_title('Child Immunization', color='green', size=15)

# plot1 = ax1.plot(df2['Year'], df2['Progress'], color=color[0],  marker='D')
# plot2 = ax1.plot(df2['Year'], df2['MileStones'], color=color[1],  marker='8', linestyle='--')
# plot3 = ax1.plot(df2['Year'], df2['Target'], color=color[2], marker = 's', linestyle='--')

# ax1.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019, 2020,2021,2022,2023,2024, 2025,2026,2027,2028,2029, 2030])
# ax1.tick_params(axis='y', labelcolor='black')
# #change_width(bar1, .7, bar1)
# #change_width(bar2, .7, bar2)
# autolabel_line(df2['Year'], df2['Progress'])
# autolabel_line(df2['Year'], df2['MileStones'])
# autolabel_line(df2['Year'], df2['Target'])

# #autolabel(bar1)
# #autolabel(bar2)
# #autolabel(bar3)

# ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

# color = 'tab:red'
# ax2.set_ylabel('Change in Progress', color='black', size=15)  # we already handled the x-label with ax1
# bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
# ax2.tick_params(axis='y', labelcolor=color)

# autolabel_line(df2['Year'], df2['pct_change'])

# #fig.tight_layout()  # otherwise the right y-label is slightly clipped
# plt.grid(axis='y', which = 'major', linestyle='--')

# plt2.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt
# import seaborn as sb

# file2 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='immunization pct_change')
# #df2 = pd.DataFrame(file2)
# df2= pd.DataFrame(file2).reset_index(drop='True')
# df2['progress_change'] = df2['Progress'].diff()
# df2['pct_change'] = df2['Progress'].pct_change()*100
# df2.fillna(0)


# fig, ax2 = plt2.subplots(figsize=(20, 10))
# color = 'tab:red'
# ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
# bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
# ax2.tick_params(axis='y', labelcolor=color)
# ax2.set_title('Child Immunization', color='green', size=15)
# ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
# autolabel_line(df2['Year'], df2['pct_change'].round())

# plt.grid(axis='y', which = 'major', linestyle='--')

# %%
def pct_change_inc(data):
    d = []
    for i in range(len(data)):
        if i == 0:
            d.append(0)
        else:
            d.append(((data[i]-data[i-1])/data[i-1] * 100).round(1))
    return d 
    
def pct_change_dec(data):
    d = []
    for i in range(len(data)):
        if i == 0:
            d.append(0)
        else:
            d.append(((data[i-1]-data[i])/data[i-1] * 100).round(1))
    return d

# %%
import matplotlib.pyplot as plt2

f311 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='3.1.1')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(f311).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
#df2['per_change'] = (( df2['Progress'].shift(1) - df2['Progress'] ) /df2['Progress'])*100

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Maternal Mortality Rate (3.1.1)', color='green', size=15)

ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])

autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000       286         0.0
# 1   2002       264         7.7
# 2   2003       254         3.8
# 3   2004       243         4.3
# 4   2005       237         2.5
# 5   2006       222         6.3
# 6   2006       276       -24.3
# 7   2007       214        22.5
# 8   2008       205         4.2
# 9   2009       199         2.9
# 10  2010       191         4.0
# 11  2011       180         5.8
# 12  2012       173         3.9
# 13  2013       166         4.0
# 14  2014       161         3.0
# 15  2015       154         4.3
# 16  2016       143         7.1
# 17  2017       140         2.1
# 18  2019       186       -32.9

# %%
f312 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='3.1.2')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(f312).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
#df2['per_change'] = (( df2['Progress'].shift(1) - df2['Progress'] ) /df2['Progress'])*100

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Skill Birth Rate (3.1.2)', color='green', size=15)

ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])

autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000        23         0.0
# 1   2004        36        56.5
# 2   2005        48        33.3
# 3   2006        39       -18.8
# 4   2007        40         2.6
# 5   2008        41         2.5
# 6   2010        43         4.9
# 7   2011        51        18.6
# 8   2012        52         2.0
# 9   2013        58        11.5
# 10  2014        59         1.7
# 11  2017        69        16.9
# 12  2018        71         2.9

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='immunization pct_change')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Child Immunization (3.b.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000        59         0.0
# 1   2004        49       -16.9
# 2   2005        49         0.0
# 3   2006        50         2.0
# 4   2007        51         2.0
# 5   2008        51         0.0
# 6   2010        53         3.9
# 7   2011        56         5.7
# 8   2012        57         1.8
# 9   2013        58         1.8
# 10  2014        57        -1.7
# 11  2018        71        24.6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='3.2.1')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Under 5 Motality Rate (3.2.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000       113         0.0
# 1   2001       105         7.1
# 2   2002       102         2.9
# 3   2003       100         2.0
# 4   2004        98         2.0
# 5   2005        96         2.0
# 6   2006        94         2.1
# 7   2007        93         1.1
# 8   2008        91         2.2
# 9   2009        89         2.2
# 10  2010        87         2.2
# 11  2011        85         2.3
# 12  2012        89        -4.7
# 13  2013        81         9.0
# 14  2014        78         3.7
# 15  2015        76         2.6
# 16  2016        74         2.6
# 17  2017        74         0.0
# 18  2018        69         6.8
# 19  2019        67         2.9

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='3.2.2')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Neonatal Mortality Rate (3.2.2)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000        60         0.0
# 1   2001        56         6.7
# 2   2002        55         1.8
# 3   2003        54         1.8
# 4   2004        53         1.9
# 5   2005        53         0.0
# 6   2006        54        -1.9
# 7   2007        52         3.7
# 8   2008        51         1.9
# 9   2009        51         0.0
# 10  2010        50         2.0
# 11  2011        49         2.0
# 12  2012        55       -12.2
# 13  2013        47        14.5
# 14  2014        56       -19.1
# 15  2015        45        19.6
# 16  2016        44         2.2
# 17  2017        42         4.5
# 18  2018        42         0.0
# 19  2019        41         2.4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='3.3.1')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('HIV Incidence (3.3.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000      0.01         0.0
# 1   2001      0.01         0.0
# 2   2002      0.01         0.0
# 3   2003      0.01         0.0
# 4   2004      0.02       100.0
# 5   2005      0.10       400.0
# 6   2006      0.09       -10.0
# 7   2007      0.11        22.2
# 8   2008      0.13        18.2
# 9   2009      0.13         0.0
# 10  2010      0.12        -7.7
# 11  2011      0.12         0.0
# 12  2012      0.13         8.3
# 13  2013      0.13         0.0
# 14  2014      0.14         7.7
# 15  2015      0.14         0.0
# 16  2016      0.15         7.1
# 17  2017      0.15         0.0
# 18  2018      0.16         6.7
# 19  2019      0.17         6.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/Pakistan at glance.xlsx', sheet_name='3.3.2')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('TB Incidence (3.3.2)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000       275         0.0
# 1   2001       275         0.0
# 2   2002       275         0.0
# 3   2003       276        -0.4
# 4   2004       276         0.0
# 5   2005       276         0.0
# 6   2006       276         0.0
# 7   2007       276         0.0
# 8   2008       276         0.0
# 9   2009       276         0.0
# 10  2010       276         0.0
# 11  2011       276         0.0
# 12  2012       276         0.0
# 13  2013       275         0.4
# 14  2014       270         1.8
# 15  2015       270         0.0
# 16  2016       268         0.7
# 17  2017       267         0.4
# 18  2018       265         0.7
# 19  2019       263         0.8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.3.3')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Malaria Incidence (3.3.3)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000      7.23         0.0
# 1   2001      7.23         0.0
# 2   2002      6.57         9.1
# 3   2003      6.14         6.5
# 4   2004      4.44        27.7
# 5   2005      5.36       -20.7
# 6   2006      5.28         1.5
# 7   2007      5.06         4.2
# 8   2008      4.53        10.5
# 9   2009      5.89       -30.0
# 10  2010      8.20       -39.2
# 11  2011     10.57       -28.9
# 12  2012      8.98        15.0
# 13  2013      7.55        15.9
# 14  2014      7.15         5.3
# 15  2015      5.06        29.2
# 16  2016      6.01       -18.8
# 17  2017      4.75        21.0
# 18  2018      3.38        28.8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.4.1')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Probability of dying from NCD (3.4.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000      24.8         0.0
# 1  2005      26.7        -7.7
# 2  2010      25.6         4.1
# 3  2015      24.8         3.1
# 4  2016      24.7         0.4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.4.2')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Suicide Mortality Rate (3.4.2)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000       2.6         0.0
# 1  2005       3.5       -34.6
# 2  2010       3.1        11.4
# 3  2015       2.1        32.3
# 4  2016       2.9       -38.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.6.1')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Road Traffic Mortality Rate (3.6.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000      15.0         0.0
# 1  2013      14.2         5.3
# 2  2015      14.2         0.0
# 3  2016      14.3        -0.7
# 4  2018      14.5        -1.4

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.7.1')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Need for family Planning (3.7.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000        35         0.0
# 1  2006        54        54.3
# 2  2012        47       -13.0
# 3  2015        47         0.0
# 4  2017        49         4.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.7.2')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Adolescent Birth Rate (3.7.2)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000        49         0.0
# 1  2002        60       -22.4
# 2  2004        52        13.3
# 3  2005        51         1.9
# 4  2009        49         3.9
# 5  2011        44        10.2
# 6  2014        38        13.6
# 7  2015        47       -23.7
# 8  2017        46         2.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.8.1')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Universal Health Coverage Index (3.8.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000        23         0.0
# 1  2005        30        30.4
# 2  2010        35        16.7
# 3  2014        40        14.3
# 4  2015        42         5.0
# 5  2017        45         7.1
# 6  2018        48         6.7

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='3.2.1a')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_dec(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Infant Mortality Rate (3.2.1a)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000        88         0.0
# 1  2006        78        11.4
# 2  2012        74         5.1
# 3  2015        65        12.2
# 4  2017        62         4.6

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='2.1.1 Family Planning')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Need for Family Planning (2.1.1)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000        35         0.0
# 1  2006        54        54.3
# 2  2012        47       -13.0
# 3  2017        49         4.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='2.1.2 Antenatal Care')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Antenatal Care (2.1.2)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2000        22         0.0
# 1  2006        28        27.3
# 2  2012        37        32.1
# 3  2017        51        37.8

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='2.1.3 Child Immunization')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)

df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Child Immunization (2.1.3)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#     Year  Progress  pct_change
# 0   2000        59         0.0
# 1   2004        49       -16.9
# 2   2005        49         0.0
# 3   2006        47        -4.1
# 4   2007        51         8.5
# 5   2008        51         0.0
# 6   2010        53         3.9
# 7   2011        56         5.7
# 8   2012        54        -3.6
# 9   2013        58         7.4
# 10  2014        57        -1.7
# 11  2017        66        15.8
# 12  2018        68         3.0

# %%
def pct_change(data):
    d = []
    for i in range(len(data)):
        if i == 0:
            d.append(0)
        else:
            d.append(((data[i]-data[i-1])/data[i-1] * 100).round(1))
    return d

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name='2.1.4 Care Seeking Behaviour')
#df2 = pd.DataFrame(file2)
df2= pd.DataFrame(file2).reset_index(drop='True')
#df2['progress_change'] = df2['Progress'].diff()
#df2['pct_change'] = df2['Progress'].pct_change()*100
df2.fillna(0)
 
df2['pct_change'] = pct_change_inc(df2['Progress'])
print(df2)

fig, ax2 = plt2.subplots(figsize=(20, 10))
color = 'tab:red'
ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_title('Care Seeking Behaviour (2.1.4)', color='green', size=15)
ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
autolabel_line(df2['Year'], df2['pct_change'].round())

plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
#    Year  Progress  pct_change
# 0  2006      58.0         0.0
# 1  2012      56.6        -2.4
# 2  2014      64.0        13.1
# 3  2017      73.9        15.5
# 4  2018      84.5        14.3

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

#file2 = pd.read_excel('E:/dashboards/sdg3/pct_change.xlsx', sheet_name=None)

file2 = pd.ExcelFile('E:/dashboards/sdg3/pct_change_all.xlsx')

sheet_to_df_map = {}
for sheet_name in file2.sheet_names:
 
    file2 = pd.read_excel('E:/dashboards/sdg3/pct_change_all.xlsx', sheet_name=sheet_name)
    df2= pd.DataFrame(file2).reset_index(drop='True')

    df2.fillna(0)
    #print(df2['Progress'].iloc[0], df2['Progress'].iloc[-1])
    
    if (df2['Progress'].iloc[0] > df2['Progress'].iloc[-1]):
        df2['pct_change'] = pct_change_dec(df2['Progress'])
    else:
        df2['pct_change'] = pct_change_inc(df2['Progress'])

    #print(df2[0:-1])

    df2 = df2[1:-1]    
    print(sheet_name)
    print(df2)
    fig, ax2 = plt2.subplots(figsize=(20, 10))
    color = 'tab:red'
    ax2.set_ylabel('Change in Progress (%)', color='black' , size=15)  # we already handled the x-label with ax1
    bar2 = ax2.plot(df2['Year'], df2['pct_change'], color=color, marker='o')
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.set_title(sheet_name, color='green', size=15)
    ax2.set_xticks([2000,2001,2002,2003,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014, 2015,2016,2017,2018,2019])
    autolabel_line(df2['Year'], df2['pct_change'].round())

    plt.grid(axis='y', which = 'major', linestyle='--')
# Out:
# 3.3.2 TB Incidence
#     Year  Progress  pct_change
# 1   2001       275         0.0
# 2   2002       275         0.0
# 3   2003       276        -0.4
# 4   2004       276         0.0
# 5   2005       276         0.0
# 6   2006       276         0.0
# 7   2007       276         0.0
# 8   2008       276         0.0
# 9   2009       276         0.0
# 10  2010       276         0.0
# 11  2011       276         0.0
# 12  2012       276         0.0
# 13  2013       275         0.4
# 14  2014       270         1.8
# 15  2015       270         0.0
# 16  2016       268         0.7
# 17  2017       267         0.4
# 18  2018       265         0.7
# 19  2019       263         0.8
# 3.3.3 Malaria Incidence
#     Year  Progress  pct_change
# 1   2001      7.23         0.0
# 2   2002      6.57         9.1
# 3   2003      6.14         6.5
# 4   2004      4.44        27.7
# 5   2005      5.36       -20.7
# 6   2006      5.28         1.5
# 7   2007      5.06         4.2
# 8   2008      4.53        10.5
# 9   2009      5.89       -30.0
# 10  2010      8.20       -39.2
# 11  2011     10.57       -28.9
# 12  2012      8.98        15.0
# 13  2013      7.55        15.9
# 14  2014      7.15         5.3
# 15  2015      5.06        29.2
# 16  2016      6.01       -18.8
# 17  2017      4.75        21.0
# 18  2018      3.38        28.8
# 3.4.1 Dying from NCD
#    Year  Progress  pct_change
# 1  2005      26.7        -7.7
# 2  2010      25.6         4.1
# 3  2015      24.8         3.1
# 4  2016      24.7         0.4
# 3.4.2 Suicide Mortality Rate
#    Year  Progress  pct_change
# 1  2005       3.5       -34.6
# 2  2010       3.1        11.4
# 3  2015       2.1        32.3
# 4  2016       2.9       -38.1
# 3.6.1 Road Traffic Mortality
#    Year  Progress  pct_change
# 1  2013      14.2         5.3
# 2  2015      14.2         0.0
# 3  2016      14.3        -0.7
# 4  2018      14.5        -1.4
# 3.7.1 Need for Family Planning
#    Year  Progress  pct_change
# 1  2006        54        54.3
# 2  2012        47       -13.0
# 3  2015        47         0.0
# 4  2017        49         4.3
# 3.7.2 Adolescent Birth Rate
#    Year  Progress  pct_change
# 1  2002        60       -22.4
# 2  2004        52        13.3
# 3  2005        51         1.9
# 4  2009        49         3.9
# 5  2011        44        10.2
# 6  2014        38        13.6
# 7  2015        47       -23.7
# 8  2017        46         2.1
# 3.8.1 UHC Index
#    Year  Progress  pct_change
# 1  2005        30        30.4
# 2  2010        35        16.7
# 3  2014        40        14.3
# 4  2015        42         5.0
# 5  2017        45         7.1
# 6  2018        48         6.7
# 3.2.1a Infant Mortality Rate
#    Year  Progress  pct_change
# 1  2006        78        11.4
# 2  2012        74         5.1
# 3  2015        65        12.2
# 4  2017        62         4.6
# 2.1.1 Family Planning
#    Year  Progress  pct_change
# 1  2006        54        54.3
# 2  2012        47       -13.0
# 3  2017        49         4.3
# 2.1.2 Antenatal Care
#    Year  Progress  pct_change
# 1  2006        28        27.3
# 2  2012        37        32.1
# 3  2017        51        37.8
# 2.1.3 Child Immunization
#     Year  Progress  pct_change
# 1   2004        49       -16.9
# 2   2005        49         0.0
# 3   2006        47        -4.1
# 4   2007        51         8.5
# 5   2008        51         0.0
# 6   2010        53         3.9
# 7   2011        56         5.7
# 8   2012        54        -3.6
# 9   2013        58         7.4
# 10  2014        57        -1.7
# 11  2017        66        15.8
# 12  2018        68         3.0
# 2.1.4 Care Seeking Behaviour
#    Year  Progress  pct_change
# 1  2012      56.6        -2.4
# 2  2014      64.0        13.1
# 3  2017      73.9        15.5
# 4  2018      84.5        14.3
# 2.2.1 TB Treatment Coverage
#     Year  Progress  pct_change
# 1   2002      12.0       130.8
# 2   2003      17.0        41.7
# 3   2004      22.0        29.4
# 4   2005      32.0        45.5
# 5   2006      39.0        21.9
# 6   2007      50.0        28.2
# 7   2008      52.0         4.0
# 8   2009      55.0         5.8
# 9   2010      53.0        -3.6
# 10  2011      52.0        -1.9
# 11  2012      52.0         0.0
# 12  2013      55.0         5.8
# 13  2014      58.0         5.5
# 14  2015      60.0         3.4
# 15  2016      65.0         8.3
# 16  2017      65.0         0.0
# 17  2018      64.0        -1.5
